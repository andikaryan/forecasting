# %% [markdown]
# # Peminjaman buku kategori agama

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import random
import altair as alt
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Reshape, GRU, Dense, Dropout, TimeDistributed
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.model_selection import ParameterGrid
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dropout
from bayes_opt import BayesianOptimization
from itertools import product

# %% [markdown]
# Read Dataset

# %%
buku_200 = pd.read_csv('D:\\KuliYeah\\Season 7\\Arc Skripsi\\forecasting\\buku_200.csv')
buku_200['Bulan'] = pd.to_datetime(buku_200['Bulan'], format='%m/%y')

# %%
buku_200.plot(x='Bulan', y='Jumlah_buku_dipinjam', kind='line')
plt.title('Jumlah Peminjaman Buku')
plt.xlabel('Tanggal')
plt.ylabel('Jumlah Peminjaman')
plt.show()

# %% [markdown]
# IQR

# %%
# Menghitung Q1, Q3 dan IQR
Q1 = buku_200['Jumlah_buku_dipinjam'].quantile(0.25)
Q3 = buku_200['Jumlah_buku_dipinjam'].quantile(0.75)
IQR = Q3 - Q1

# Batas bawah dan atas untuk outlier
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
buku_200
outliers_000 = buku_200[(buku_200['Jumlah_buku_dipinjam'] < lower_bound) | (buku_200['Jumlah_buku_dipinjam'] > upper_bound)]

print(outliers_000)
# Menampilkan batas bawah dan atas
print(f"Batas bawah: {lower_bound}")
print(f"Batas atas: {upper_bound}")

plt.figure(figsize=(8, 6))
sns.boxplot(x=buku_200['Jumlah_buku_dipinjam'])
plt.xlabel('Jumlah Peminjaman')
plt.ylabel('Jumlah Buku')
# Out:
#         Bulan  Jumlah_buku_dipinjam
# 2  2017-03-01                   682
# 14 2018-03-01                   701
# 26 2019-03-01                   833
# 32 2019-09-01                   909
# 37 2020-02-01                   935
# Batas bawah: -273.0
# Batas atas: 669.0
# Text(0, 0.5, 'Jumlah Buku')

# %% [markdown]
# Hyperparameter Tuning

# %%
# Rentang hyperparameter
window_sizes = [3, 8, 9]  # Contoh rentang window size
tolerances = [0.5, 1, 2, 2.5, 3]  # Contoh rentang tolerance

# Buat grid kombinasi hyperparameter
grid = list(product(window_sizes, tolerances))

# Simpan hasil tuning
results = []

for window_size, tolerance in grid:
    for tolerance in tolerances:
        buku_200_copy = buku_200.copy()  # Buat salinan data asli agar tidak merusak data asli

        # Rolling median dan rolling std
        buku_200_copy['rolling_median'] = buku_200_copy['Jumlah_buku_dipinjam'].rolling(window=window_size, center=True).median()
        buku_200_copy['rolling_std'] = buku_200_copy['Jumlah_buku_dipinjam'].rolling(window=window_size, center=True).std()

        # Batas atas dan bawah
        upper_bound = buku_200_copy['rolling_median'] + tolerance * buku_200_copy['rolling_std']
        lower_bound = buku_200_copy['rolling_median'] - tolerance * buku_200_copy['rolling_std']

        # Deteksi ou    tlier awal
        detected_outliers = (buku_200_copy['Jumlah_buku_dipinjam'] > upper_bound) | \
                            (buku_200_copy['Jumlah_buku_dipinjam'] < lower_bound)

        # Ganti outlier dengan rolling median
        buku_200_cleaned = buku_200_copy['Jumlah_buku_dipinjam'].copy()
        detected_outliers = (buku_200_copy['Jumlah_buku_dipinjam'] > upper_bound) | \
                            (buku_200_copy['Jumlah_buku_dipinjam'] < lower_bound)
        buku_200_cleaned[detected_outliers] = buku_200_copy['rolling_median'][detected_outliers]


        # Forecasting (contoh dummy prediksi)
        y_actual = buku_200_cleaned[10:]  # Data aktual (tes)
        y_pred = buku_200_cleaned.shift(1)[10:]  # Dummy prediksi

        # Hitung metrik evaluasi
        mape = mean_absolute_percentage_error(y_actual, y_pred)
        rmse = np.sqrt(mean_squared_error(y_actual, y_pred))

        # Simpan hasil
        results.append({
            'window_size': window_size,
            'tolerance': tolerance,
            'mape': mape,
            'rmse': rmse
        })

# Analisis hasil
results_df = pd.DataFrame(results)
best_result = results_df.sort_values(by='rmse').iloc[0]
print("Kombinasi terbaik berdasarkan MAPE & RMSE: ")
print(best_result)
# Tampilkan semua hasil tuning dari grid search
print("\nSeluruh hasil kombinasi hyperparameter rolling window median:")
for res in results:
    print(f"window_size: {res['window_size']}, Tolerance: {res['tolerance']} -> RMSE: {res['rmse']:.3f}")
# Simpan hasil grid search ke file Excel
results_df.to_excel("rwm buku_200.xlsx", index=False)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_22404\1733997197.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[297.5 385.  381.5 358.5 313.5 366.  485.  445.  366.  302.5 302.5 398.5
#  385.  362.5 426.  527.5 450.  426.  437.  514.5 463.5 445.  422.  422.
#   31.   17.   21.   31.   26.   26.   17.   77.  111.5 122.5 112.5 112.
#  107.5 123.  115.  122.5 122.5  96.5 100.  100.   85.   85.  111.5 112.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_200_cleaned[detected_outliers] = buku_200_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_22404\1733997197.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[385.  381.5 358.5 313.5 485.  366.  302.5 385.  362.5 426.  450.  514.5
#  445.  422.   31.   26.   17.   77.  111.5 112.5 107.5 123.  115.  122.5
#  122.5  85.  111.5 112.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_200_cleaned[detected_outliers] = buku_200_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_22404\1733997197.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[450.  445.  422.  112.5  85.  111.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_200_cleaned[detected_outliers] = buku_200_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_22404\1733997197.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[112.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_200_cleaned[detected_outliers] = buku_200_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_22404\1733997197.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[297.5 385.  381.5 358.5 313.5 366.  485.  445.  366.  302.5 302.5 398.5
#  385.  362.5 426.  527.5 450.  426.  437.  514.5 463.5 445.  422.  422.
#   31.   17.   21.   31.   26.   26.   17.   77.  111.5 122.5 112.5 112.
#  107.5 123.  115.  122.5 122.5  96.5 100.  100.   85.   85.  111.5 112.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_200_cleaned[detected_outliers] = buku_200_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_22404\1733997197.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[385.  381.5 358.5 313.5 485.  366.  302.5 385.  362.5 426.  450.  514.5
#  445.  422.   31.   26.   17.   77.  111.5 112.5 107.5 123.  115.  122.5
#  122.5  85.  111.5 112.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_200_cleaned[detected_outliers] = buku_200_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_22404\1733997197.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[450.  445.  422.  112.5  85.  111.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_200_cleaned[detected_outliers] = buku_200_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_22404\1733997197.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[112.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_200_cleaned[detected_outliers] = buku_200_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_22404\1733997197.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[297.5 385.  381.5 358.5 313.5 366.  485.  445.  366.  302.5 302.5 398.5
#  385.  362.5 426.  527.5 450.  426.  437.  514.5 463.5 445.  422.  422.
#   31.   17.   21.   31.   26.   26.   17.   77.  111.5 122.5 112.5 112.
#  107.5 123.  115.  122.5 122.5  96.5 100.  100.   85.   85.  111.5 112.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_200_cleaned[detected_outliers] = buku_200_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_22404\1733997197.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[385.  381.5 358.5 313.5 485.  366.  302.5 385.  362.5 426.  450.  514.5
#  445.  422.   31.   26.   17.   77.  111.5 112.5 107.5 123.  115.  122.5
#  122.5  85.  111.5 112.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_200_cleaned[detected_outliers] = buku_200_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_22404\1733997197.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[450.  445.  422.  112.5  85.  111.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_200_cleaned[detected_outliers] = buku_200_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_22404\1733997197.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[112.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_200_cleaned[detected_outliers] = buku_200_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_22404\1733997197.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[297.5 385.  381.5 358.5 313.5 366.  485.  445.  366.  302.5 302.5 398.5
#  385.  362.5 426.  527.5 450.  426.  437.  514.5 463.5 445.  422.  422.
#   31.   17.   21.   31.   26.   26.   17.   77.  111.5 122.5 112.5 112.
#  107.5 123.  115.  122.5 122.5  96.5 100.  100.   85.   85.  111.5 112.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_200_cleaned[detected_outliers] = buku_200_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_22404\1733997197.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[385.  381.5 358.5 313.5 485.  366.  302.5 385.  362.5 426.  450.  514.5
#  445.  422.   31.   26.   17.   77.  111.5 112.5 107.5 123.  115.  122.5
#  122.5  85.  111.5 112.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_200_cleaned[detected_outliers] = buku_200_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_22404\1733997197.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[450.  445.  422.  112.5  85.  111.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_200_cleaned[detected_outliers] = buku_200_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_22404\1733997197.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[112.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_200_cleaned[detected_outliers] = buku_200_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_22404\1733997197.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[297.5 385.  381.5 358.5 313.5 366.  485.  445.  366.  302.5 302.5 398.5
#  385.  362.5 426.  527.5 450.  426.  437.  514.5 463.5 445.  422.  422.
#   31.   17.   21.   31.   26.   26.   17.   77.  111.5 122.5 112.5 112.
#  107.5 123.  115.  122.5 122.5  96.5 100.  100.   85.   85.  111.5 112.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_200_cleaned[detected_outliers] = buku_200_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_22404\1733997197.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[385.  381.5 358.5 313.5 485.  366.  302.5 385.  362.5 426.  450.  514.5
#  445.  422.   31.   26.   17.   77.  111.5 112.5 107.5 123.  115.  122.5
#  122.5  85.  111.5 112.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_200_cleaned[detected_outliers] = buku_200_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_22404\1733997197.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[450.  445.  422.  112.5  85.  111.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_200_cleaned[detected_outliers] = buku_200_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_22404\1733997197.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[112.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_200_cleaned[detected_outliers] = buku_200_copy['rolling_median'][detected_outliers]
# Kombinasi terbaik berdasarkan MAPE & RMSE:
# window_size     8.000000
# tolerance       0.500000
# mape            0.248254
# rmse           40.710228
# Name: 25, dtype: float64
#
# Seluruh hasil kombinasi hyperparameter rolling window median:
# window_size: 3, Tolerance: 0.5 -> RMSE: 88.308
# window_size: 3, Tolerance: 1 -> RMSE: 95.769
# window_size: 3, Tolerance: 2 -> RMSE: 165.800
# window_size: 3, Tolerance: 2.5 -> RMSE: 165.800
# window_size: 3, Tolerance: 3 -> RMSE: 165.800
# window_size: 3, Tolerance: 0.5 -> RMSE: 88.308
# window_size: 3, Tolerance: 1 -> RMSE: 95.769
# window_size: 3, Tolerance: 2 -> RMSE: 165.800
# window_size: 3, Tolerance: 2.5 -> RMSE: 165.800
# window_size: 3, Tolerance: 3 -> RMSE: 165.800
# window_size: 3, Tolerance: 0.5 -> RMSE: 88.308
# window_size: 3, Tolerance: 1 -> RMSE: 95.769
# window_size: 3, Tolerance: 2 -> RMSE: 165.800
# window_size: 3, Tolerance: 2.5 -> RMSE: 165.800
# window_size: 3, Tolerance: 3 -> RMSE: 165.800
# window_size: 3, Tolerance: 0.5 -> RMSE: 88.308
# window_size: 3, Tolerance: 1 -> RMSE: 95.769
# window_size: 3, Tolerance: 2 -> RMSE: 165.800
# window_size: 3, Tolerance: 2.5 -> RMSE: 165.800
# window_size: 3, Tolerance: 3 -> RMSE: 165.800
# window_size: 3, Tolerance: 0.5 -> RMSE: 88.308
# window_size: 3, Tolerance: 1 -> RMSE: 95.769
# window_size: 3, Tolerance: 2 -> RMSE: 165.800
# window_size: 3, Tolerance: 2.5 -> RMSE: 165.800
# window_size: 3, Tolerance: 3 -> RMSE: 165.800
# window_size: 8, Tolerance: 0.5 -> RMSE: 40.710
# window_size: 8, Tolerance: 1 -> RMSE: 75.734
# window_size: 8, Tolerance: 2 -> RMSE: 103.408
# window_size: 8, Tolerance: 2.5 -> RMSE: 164.484
# window_size: 8, Tolerance: 3 -> RMSE: 165.800
# window_size: 8, Tolerance: 0.5 -> RMSE: 40.710
# window_size: 8, Tolerance: 1 -> RMSE: 75.734
# window_size: 8, Tolerance: 2 -> RMSE: 103.408
# window_size: 8, Tolerance: 2.5 -> RMSE: 164.484
# window_size: 8, Tolerance: 3 -> RMSE: 165.800
# window_size: 8, Tolerance: 0.5 -> RMSE: 40.710
# window_size: 8, Tolerance: 1 -> RMSE: 75.734
# window_size: 8, Tolerance: 2 -> RMSE: 103.408
# window_size: 8, Tolerance: 2.5 -> RMSE: 164.484
# window_size: 8, Tolerance: 3 -> RMSE: 165.800
# window_size: 8, Tolerance: 0.5 -> RMSE: 40.710
# window_size: 8, Tolerance: 1 -> RMSE: 75.734
# window_size: 8, Tolerance: 2 -> RMSE: 103.408
# window_size: 8, Tolerance: 2.5 -> RMSE: 164.484
# window_size: 8, Tolerance: 3 -> RMSE: 165.800
# window_size: 8, Tolerance: 0.5 -> RMSE: 40.710
# window_size: 8, Tolerance: 1 -> RMSE: 75.734
# window_size: 8, Tolerance: 2 -> RMSE: 103.408
# window_size: 8, Tolerance: 2.5 -> RMSE: 164.484
# window_size: 8, Tolerance: 3 -> RMSE: 165.800
# window_size: 9, Tolerance: 0.5 -> RMSE: 47.267
# window_size: 9, Tolerance: 1 -> RMSE: 80.059
# window_size: 9, Tolerance: 2 -> RMSE: 127.200
# window_size: 9, Tolerance: 2.5 -> RMSE: 164.483
# window_size: 9, Tolerance: 3 -> RMSE: 165.800
# window_size: 9, Tolerance: 0.5 -> RMSE: 47.267
# window_size: 9, Tolerance: 1 -> RMSE: 80.059
# window_size: 9, Tolerance: 2 -> RMSE: 127.200
# window_size: 9, Tolerance: 2.5 -> RMSE: 164.483
# window_size: 9, Tolerance: 3 -> RMSE: 165.800
# window_size: 9, Tolerance: 0.5 -> RMSE: 47.267
# window_size: 9, Tolerance: 1 -> RMSE: 80.059
# window_size: 9, Tolerance: 2 -> RMSE: 127.200
# window_size: 9, Tolerance: 2.5 -> RMSE: 164.483
# window_size: 9, Tolerance: 3 -> RMSE: 165.800
# window_size: 9, Tolerance: 0.5 -> RMSE: 47.267
# window_size: 9, Tolerance: 1 -> RMSE: 80.059
# window_size: 9, Tolerance: 2 -> RMSE: 127.200
# window_size: 9, Tolerance: 2.5 -> RMSE: 164.483
# window_size: 9, Tolerance: 3 -> RMSE: 165.800
# window_size: 9, Tolerance: 0.5 -> RMSE: 47.267
# window_size: 9, Tolerance: 1 -> RMSE: 80.059
# window_size: 9, Tolerance: 2 -> RMSE: 127.200
# window_size: 9, Tolerance: 2.5 -> RMSE: 164.483
# window_size: 9, Tolerance: 3 -> RMSE: 165.800

# %% [markdown]
# Outlier handling Rolling Window Median

# %%
# Ambil kombinasi hyperparameter terbaik
best_window_size = 8
best_tolerance = 0.5

# Salin data asli
buku_200_copy = buku_200.copy()

# Rolling median dan rolling std
buku_200_copy['rolling_median'] = buku_200_copy['Jumlah_buku_dipinjam'].rolling(window=best_window_size, center=True).median()
buku_200_copy['rolling_std'] = buku_200_copy['Jumlah_buku_dipinjam'].rolling(window=best_window_size, center=True).std()

# Batas atas dan bawah
upper_bound = buku_200_copy['rolling_median'] + best_tolerance * buku_200_copy['rolling_std']
lower_bound = buku_200_copy['rolling_median'] - best_tolerance * buku_200_copy['rolling_std']

# Deteksi outlier awal
detected_outliers = (buku_200_copy['Jumlah_buku_dipinjam'] > upper_bound) | \
                    (buku_200_copy['Jumlah_buku_dipinjam'] < lower_bound)

# Ganti outlier dengan rolling median
buku_200_copy.loc[detected_outliers, 'Jumlah_buku_dipinjam'] = buku_200_copy.loc[detected_outliers, 'rolling_median']

# Buat DataFrame untuk visualisasi
buku_200_copy['Status'] = 'Setelah Outlier Handling'
buku_200['Status'] = 'Sebelum Outlier Handling'

df_visual = pd.concat([buku_200[['Jumlah_buku_dipinjam', 'Status']], 
                    buku_200_copy[['Jumlah_buku_dipinjam', 'Status']]])

# Plot Boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(x='Status', y='Jumlah_buku_dipinjam', data=df_visual)
plt.show()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_22404\503463169.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[297.5 385.  381.5 358.5 313.5 366.  485.  445.  366.  302.5 302.5 398.5
#  385.  362.5 426.  527.5 450.  426.  437.  514.5 463.5 445.  422.  422.
#   31.   17.   21.   31.   26.   26.   17.   77.  111.5 122.5 112.5 112.
#  107.5 123.  115.  122.5 122.5  96.5 100.  100.   85.   85.  111.5 112.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_200_copy.loc[detected_outliers, 'Jumlah_buku_dipinjam'] = buku_200_copy.loc[detected_outliers, 'rolling_median']

# %%
plt.figure(figsize=(12, 6))
plt.plot(buku_200['Bulan'], buku_200['Jumlah_buku_dipinjam'], label='Sebelum Outlier Handling')
plt.plot(buku_200_copy['Bulan'], buku_200_copy['Jumlah_buku_dipinjam'], label='Setelah Outlier Handling', color='orange')
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.show()

# %%
# Ambil data asli sebelum normalisasi untuk referensi
data_original = buku_200_copy[['Jumlah_buku_dipinjam']].values
bulan = buku_200_copy['Bulan'].values  # Ambil label bulan

# Ukuran figure
plt.figure(figsize=(14, 6))

# Daftar rasio split yang ingin ditampilkan
split_ratios = [0.6, 0.7, 0.8]
colors = ['green', 'orange', 'blue']
labels = ['70:30', '80:20', '90:10']

# Plot data original untuk semua bulan sebagai latar
plt.plot(bulan, data_original, label='Data Asli', color='black', alpha=0.5)

# Loop untuk setiap rasio split
for ratio, color, label in zip(split_ratios, colors, labels):
    split_idx = int(len(data_original) * ratio)
    data_train = data_original[:split_idx]
    data_test = data_original[split_idx:]

    bulan_train = bulan[:split_idx]
    bulan_test = bulan[split_idx:]

    # Plot garis split
    plt.axvline(x=bulan[split_idx], color=color, linestyle='--', label=f'Split {label}')

# Label dan tampilan
plt.xticks(rotation=45)
plt.xlabel('Bulan')
plt.ylabel('Jumlah Buku Dipinjam')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Data split 60:40

# %% [markdown]
# Hyperparameter Tunning

# %%
# Data awal
X_raw = buku_200_copy[['Jumlah_buku_dipinjam']].values

# Fungsi membuat data dengan timestep
def create_timestep_data(data, timestep):
    X, y = [], []
    for i in range(len(data) - timestep):
        X.append(data[i:i+timestep])
        y.append(data[i+timestep])
    return np.array(X), np.array(y)

# Grid Search Parameter
param_grid = {
    'timestep': [12, 24],
    'epochs': [50, 100, 170],
    'batch_size': [32, 64, 128],
    'gru_units': [10, 20, 100],
    'cnn_filters': [16, 32, 128],
}

# Inisialisasi variabel terbaik
best_rmse = float('inf')
best_params = None
results = []

# Iterasi seluruh kombinasi parameter
for params in ParameterGrid(param_grid):
    timestep = params['timestep']
    print(f"\nTesting combination: {params}")

    # Buat ulang data dengan timestep baru
    X, y = create_timestep_data(X_raw, timestep)

    # Split train-test (tanpa shuffle)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, shuffle=False)

    # Reshape data agar sesuai dengan input model CNN-GRU
    X_train = X_train.reshape((X_train.shape[0], timestep, 1))
    X_test = X_test.reshape((X_test.shape[0], timestep, 1))

    # Normalisasi target
    scaler = MinMaxScaler()
    y_train_scaled = scaler.fit_transform(y_train.reshape(-1, 1))
    y_test_scaled = scaler.transform(y_test.reshape(-1, 1))

    # Bangun model CNN-GRU
    model = Sequential()

    # CNN Layer
    model.add(Conv1D(filters=params['cnn_filters'], kernel_size=1, activation='relu', input_shape=(timestep, 1)))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Flatten())  

    # Reshape sebelum masuk ke GRU
    model.add(Reshape((1, -1)))

    # GRU Layer
    model.add(GRU(params['gru_units'], activation='relu'))  
    model.add(Dropout(0.2))  

    # Output Layer
    model.add(Dense(1))

    # Compile model
    model.compile(optimizer='adam', loss='mean_squared_error')

    # Train model
    model.fit(X_train, y_train_scaled, epochs=params['epochs'], batch_size=params['batch_size'], verbose=0)
    
    # Evaluate model
    y_pred = model.predict(X_test)
    y_pred_inverse = scaler.inverse_transform(y_pred)
    y_test_inverse = scaler.inverse_transform(y_test_scaled)
    
    mse = mean_squared_error(y_test_inverse, y_pred_inverse)
    rmse = np.sqrt(mse)

    print(f"RMSE: {rmse}")

    # Simpan hasil tuning
    results.append((params, rmse))
    
    # Simpan kombinasi terbaik
    if rmse < best_rmse:
        best_rmse = rmse
        best_params = params

# Print hasil terbaik
print(f"\nBest RMSE: {best_rmse}")
print(f"Best parameters: {best_params}")

# Display seluruh hasil tuning
for res in results:
    print(f"Params: {res[0]} -> RMSE: {res[1]}")

# Simpan hasil tuning ke Excel
results_df = pd.DataFrame([
    {
        'timestep': r[0]['timestep'],
        'epochs': r[0]['epochs'],
        'batch_size': r[0]['batch_size'],
        'gru_units': r[0]['gru_units'],
        'cnn_filters': r[0]['cnn_filters'],
        'RMSE': r[1]
    }
    for r in results
])

# Simpan ke file Excel
results_df.to_excel("tuning buku_200 60,40.xlsx", index=False)
# Out:
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# RMSE: 68.22319097418271
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# RMSE: 101.43184916727483
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/stepWARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001227EFF0F70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# RMSE: 80.30282811340496
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001227C654040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# RMSE: 1911.650528112806
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# RMSE: 359.3363808492401
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# RMSE: 463.4492055991853
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# RMSE: 125.46717501739523
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# RMSE: 243.38152501278097
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# RMSE: 604.030375336764
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 1022.6583297259932
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# RMSE: 424.0380137271062
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 710.847465055611
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# RMSE: 77.97423000840183
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# RMSE: 23.43159303544297
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# RMSE: 437.0731446247158
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 209.7785875365885
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# RMSE: 237.80393929102848
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# RMSE: 585.344008133805
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# RMSE: 158.78221658148664
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 91.86143001512741
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# RMSE: 247.2450057948862
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 150.94156913978006
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# RMSE: 332.87978781118625
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# RMSE: 544.8346678959925
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# RMSE: 149.75816917598902
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# RMSE: 110.7986472952001
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# RMSE: 163.4174420040853
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# RMSE: 225.6816709780361
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# RMSE: 177.99220449754287
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 369.6672288510274
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# RMSE: 742.8900276487336
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 99.47227122422507
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# RMSE: 222.52814608374058
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 156.57176114823025
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# RMSE: 349.61893101599065
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 130.48445482639875
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# RMSE: 69.9256370081535
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# RMSE: 89.40143518160578
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# RMSE: 263.8677966054775
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 96.83405743865632
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# RMSE: 115.84822216797726
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# RMSE: 166.41941694230016
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# RMSE: 89.24335394549638
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 87.24577886036057
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# RMSE: 99.8029382827543
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 121.91159592579537
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# RMSE: 152.88086194429977
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# RMSE: 222.07600860006437
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# RMSE: 37.16864929074254
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 69.24425579758613
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# RMSE: 64.93126177069922
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# RMSE: 90.18686014493257
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# RMSE: 53.61815055285416
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# RMSE: 77.14010102085369
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# RMSE: 559.2697834396971
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# RMSE: 87.85473262811067
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# RMSE: 275.4918749303265
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# RMSE: 717.4856822177322
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# RMSE: 376.45978106910474
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 1311.4082848768414
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# RMSE: 1058.42492887532
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# RMSE: 792.7720047262368
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# RMSE: 186.32565449742188
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# RMSE: 361.2542457690178
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# RMSE: 770.2392242891101
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 369.0068146787138
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# RMSE: 356.5982220782137
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# RMSE: 95.00398393393579
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# RMSE: 176.43447960863293
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 58.55249928246858
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# RMSE: 120.17338444163637
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 1119.8232202156646
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# RMSE: 91.08753220653162
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# RMSE: 97.32496707430782
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# RMSE: 178.03255607938985
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 756.5303348847085
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# RMSE: 453.3182544723182
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# RMSE: 633.5561063024885
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# RMSE: 195.4784089243289
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# RMSE: 110.91043669852363
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# RMSE: 546.8385314133234
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# RMSE: 303.48000511364967
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# RMSE: 244.82225927199153
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# RMSE: 477.3307711479345
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# ...
# Params: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 99.47227122422507
# Params: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 222.52814608374058
# Params: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 156.57176114823025
# Params: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 349.61893101599065
# Params: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 130.48445482639875
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 69.9256370081535
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 89.40143518160578
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 263.8677966054775
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 96.83405743865632
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 115.84822216797726
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 166.41941694230016
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 89.24335394549638
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 87.24577886036057
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 99.8029382827543
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 121.91159592579537
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 152.88086194429977
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 222.07600860006437
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 37.16864929074254
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 69.24425579758613
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 64.93126177069922
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 90.18686014493257
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 53.61815055285416
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 77.14010102085369
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 559.2697834396971
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 87.85473262811067
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 275.4918749303265
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 717.4856822177322
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 376.45978106910474
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 1311.4082848768414
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 1058.42492887532
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 792.7720047262368
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 186.32565449742188
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 361.2542457690178
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 770.2392242891101
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 369.0068146787138
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 356.5982220782137
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 95.00398393393579
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 176.43447960863293
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 58.55249928246858
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 120.17338444163637
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 1119.8232202156646
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 91.08753220653162
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 97.32496707430782
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 178.03255607938985
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 756.5303348847085
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 453.3182544723182
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 633.5561063024885
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 195.4784089243289
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 110.91043669852363
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 546.8385314133234
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 303.48000511364967
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 244.82225927199153
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 477.3307711479345
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 94.87866849504043
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 63.60227704316908
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 272.891345469119
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 83.32940986382773
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 174.08838742295276
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 344.518991019674
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 86.7617911566445
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 88.20838237477325
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 95.99289677048617
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 98.95830802935077
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 204.2164553190996
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 336.14755370313236
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 95.27925040619378
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 98.17836253305144
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 92.39110204565267
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 192.28749705589607
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 69.30610266388281
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 118.67925858363702
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 26.78729846969715
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 74.32624468736203
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 65.06150110569754
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 91.21048310602207
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 117.69595845414466
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 155.04340150019837
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 256.6730665608714
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 95.56543494361667
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 1381.9650694959557
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 509.1851651426028
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 345.7380724695968
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 357.9383222213593
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 1013.5726898011172
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 1046.4102915906608
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 609.7838237907796
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 338.88900095867155
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 251.41744370515116
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 497.7599856695213
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 102.91519386377897
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 467.54629653922007
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 246.3147714504339
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 818.370940846602
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 773.2444025588368
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 680.7737658395276
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 90.47365560221074
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 466.7468287872124
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 573.9718452876275
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 523.0555239258996
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 274.5300723320657
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 453.1671658055293
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 68.04934539481958
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 162.45325587729494
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 179.76673863895542
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 265.3096125676227
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 247.14592904119786
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 422.4798618576694
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 70.4906056021092
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 204.55461419297623
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 756.3790535998935
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 313.71106467717055
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 93.59482317831933
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 426.07205986241
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 84.78098986929244
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 97.1707108733078
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 95.79934958049651
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 157.31303108134358
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 147.4804970511301
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 91.83457283316956
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 74.0680255384898
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 74.59348905750736
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 82.80671638100794
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 39.87153672749988
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 121.73809120799525
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 182.32987322977627
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 267.82053103159154
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 89.17501586708998
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 105.57635272515823
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 355.61905596071733
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 104.2758667695429
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 70.16970926616864

# %% [markdown]
# Model CNN-GRU

# %%
# Parameter window size
timestep = 24  # Menggunakan 6 bulan terakhir sebagai input

# Membentuk data input dengan sliding window
def create_sliding_window(data, timestep):
    X, y = [], []
    for i in range(len(data) - timestep):
        X.append(data[i:i+timestep])
        y.append(data[i+timestep])
    return np.array(X), np.array(y)

# Memisahkan fitur dan target
X = buku_200_copy[['Jumlah_buku_dipinjam']].values
y = buku_200_copy[['Jumlah_buku_dipinjam']].values

# Normalisasi data
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Membuat dataset sliding window
X_window, y_window = create_sliding_window(X_scaled, timestep)

# Split data menjadi train dan test (80% training, 20% testing)
split_idx = int(len(X_window) * 0.6)
X_train, X_test = X_window[:split_idx], X_window[split_idx:]
y_train, y_test = y_window[:split_idx], y_window[split_idx:]

# Reshape input menjadi tiga dimensi (samples, timesteps, features)
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Membangun Model CNN-GRU
model_cnn_gru = Sequential()

# Lapisan CNN
model_cnn_gru.add(Conv1D(filters=16, kernel_size=1, activation='relu', input_shape=(timestep, 1)))
model_cnn_gru.add(MaxPooling1D(pool_size=2))
model_cnn_gru.add(Flatten())

# Ubah kembali ke bentuk tiga dimensi untuk input ke GRU
model_cnn_gru.add(Reshape((1, -1)))

# Lapisan GRU setelah CNN
model_cnn_gru.add(GRU(10, activation='relu'))
model_cnn_gru.add(Dropout(0.2))

# Lapisan output
model_cnn_gru.add(Dense(1))

# Kompilasi model
model_cnn_gru.compile(optimizer='adam', loss='mean_squared_error')

# Latih model
history_model = model_cnn_gru.fit(X_train, y_train, epochs=170, batch_size=32)

# Prediksi pada data uji
y_pred_cnn_gru = model_cnn_gru.predict(X_test)

# Konversi kembali ke skala asli
y_pred_cnn_gru_inverse = scaler.inverse_transform(y_pred_cnn_gru)
y_test_inverse = scaler.inverse_transform(y_test)

# Evaluasi model
mse = mean_squared_error(y_test_inverse, y_pred_cnn_gru_inverse)
rmse = np.sqrt(mse)
mape = mean_absolute_percentage_error(y_test_inverse, y_pred_cnn_gru_inverse) * 100
mae = mean_absolute_error(y_test_inverse, y_pred_cnn_gru_inverse)

print(f"RMSE: {rmse}")
print(f"MAPE: {mape:.2f}%")

# Plot hasil model (data aktual vs prediksi)
plt.figure(figsize=(14, 6))
plt.plot(buku_200_copy['Bulan'][-len(y_test_inverse):], y_test_inverse, label='Actual', color='blue')
plt.plot(buku_200_copy['Bulan'][-len(y_pred_cnn_gru_inverse):], y_pred_cnn_gru_inverse, label='Predicted', linestyle='--', color='red')
plt.title('Perbandingan Hasil Model CNN-GRU pada Data Uji')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Buku Dipinjam')
plt.legend()
plt.show()

# plot loss
plt.figure(figsize=(14, 6))
plt.plot(history_model.history['loss'], label='Train Loss')
plt.title('Loss History')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - loss: 0.1703
# Epoch 2/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.1057
# Epoch 3/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0805
# Epoch 4/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0969
# Epoch 5/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0803
# Epoch 6/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0544
# Epoch 7/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0513
# Epoch 8/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0766
# Epoch 9/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0614
# Epoch 10/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0424
# Epoch 11/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0640
# Epoch 12/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0473
# Epoch 13/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0552
# Epoch 14/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0617
# Epoch 15/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0573
# Epoch 16/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0462
# Epoch 17/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0460
# Epoch 18/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0372
# Epoch 19/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0549
# Epoch 20/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0527
# Epoch 21/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0468
# Epoch 22/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0372
# Epoch 23/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0365
# Epoch 24/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0504
# Epoch 25/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0290
# Epoch 26/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0400
# Epoch 27/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0260
# Epoch 28/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0417
# Epoch 29/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0343
# Epoch 30/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0303
# Epoch 31/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0525
# Epoch 32/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0413
# Epoch 33/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0352
# Epoch 34/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0450
# Epoch 35/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0332
# Epoch 36/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0394
# Epoch 37/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0257
# Epoch 38/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0260
# Epoch 39/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0243
# Epoch 40/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0333
# Epoch 41/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0288
# Epoch 42/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0279
# Epoch 43/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0270
# Epoch 44/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0216
# Epoch 45/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0278
# Epoch 46/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0251
# Epoch 47/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0206
# Epoch 48/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0162
# Epoch 49/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0311
# Epoch 50/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0226
# Epoch 51/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0283
# Epoch 52/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0285
# Epoch 53/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0368
# Epoch 54/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0184
# Epoch 55/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0210
# Epoch 56/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0197
# Epoch 57/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0219
# Epoch 58/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0323
# Epoch 59/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0208
# Epoch 60/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0295
# Epoch 61/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0307
# Epoch 62/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0306
# Epoch 63/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0210
# Epoch 64/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0262
# Epoch 65/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0180
# Epoch 66/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0212
# Epoch 67/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0292
# Epoch 68/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0234
# Epoch 69/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0291
# Epoch 70/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0268
# Epoch 71/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0217
# Epoch 72/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0180
# Epoch 73/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0245
# Epoch 74/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0227
# Epoch 75/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0142
# Epoch 76/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0213
# Epoch 77/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0323
# Epoch 78/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0192
# Epoch 79/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0111
# Epoch 80/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0184
# Epoch 81/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0248
# Epoch 82/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0244
# Epoch 83/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0140
# Epoch 84/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0242
# Epoch 85/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0129
# Epoch 86/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0168
# Epoch 87/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0168
# Epoch 88/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0257
# Epoch 89/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0246
# Epoch 90/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0253
# Epoch 91/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0300
# Epoch 92/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0152
# Epoch 93/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.0370
# Epoch 94/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0189
# Epoch 95/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0273
# Epoch 96/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.0233
# Epoch 97/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0135
# Epoch 98/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0203
# Epoch 99/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0183
# Epoch 100/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0346
# Epoch 101/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0198
# Epoch 102/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0213
# Epoch 103/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0101
# Epoch 104/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0200
# Epoch 105/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0186
# Epoch 106/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0224
# Epoch 107/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0182
# Epoch 108/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0367
# Epoch 109/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0148
# Epoch 110/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0179
# Epoch 111/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0206
# Epoch 112/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0283
# Epoch 113/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0208
# Epoch 114/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0111
# Epoch 115/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0204
# Epoch 116/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0142
# Epoch 117/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0234
# Epoch 118/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0182
# Epoch 119/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0182
# Epoch 120/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0169
# Epoch 121/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0143
# Epoch 122/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0216
# Epoch 123/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0163
# Epoch 124/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0148
# Epoch 125/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0146
# Epoch 126/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0143
# Epoch 127/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0273
# Epoch 128/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0146
# Epoch 129/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0200
# Epoch 130/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0278
# Epoch 131/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0215
# Epoch 132/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0308
# Epoch 133/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0100
# Epoch 134/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0124
# Epoch 135/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0175
# Epoch 136/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0104
# Epoch 137/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0179
# Epoch 138/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0191
# Epoch 139/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0241
# Epoch 140/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0174
# Epoch 141/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0167
# Epoch 142/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0193
# Epoch 143/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0207
# Epoch 144/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0157
# Epoch 145/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0163
# Epoch 146/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0186
# Epoch 147/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0192
# Epoch 148/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0181
# Epoch 149/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0221
# Epoch 150/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0131
# Epoch 151/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0062
# Epoch 152/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0127
# Epoch 153/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0193
# Epoch 154/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0137
# Epoch 155/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0104
# Epoch 156/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0221
# Epoch 157/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0177
# Epoch 158/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0207
# Epoch 159/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0133
# Epoch 160/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0168
# Epoch 161/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0100
# Epoch 162/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0142
# Epoch 163/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0176
# Epoch 164/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0136
# Epoch 165/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0102
# Epoch 166/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0202
# Epoch 167/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0108
# Epoch 168/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0100
# Epoch 169/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0143
# Epoch 170/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0187
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# RMSE: 19.06266220332444
# MAPE: 16.25%

# %%
# Prediksi 12 bulan ke depan menggunakan sliding window
def predict_future(model, last_input, months=12):
    future_predictions = []
    current_input = last_input.copy()

    for _ in range(months):
        prediction = model.predict(current_input.reshape((1, timestep, 1)))
        future_predictions.append(prediction[0, 0])
        
        # Geser input window dengan menambahkan prediksi terbaru
        current_input = np.roll(current_input, -1)
        current_input[-1] = prediction[0, 0]

    return np.array(future_predictions).reshape(-1, 1)

# Gunakan data terakhir sebagai input awal
last_input = X_scaled[-timestep:]
future_preds_scaled = predict_future(model_cnn_gru, last_input, months=12)

# Cek nilai sebelum inverse transform
print("Prediksi dalam skala normalisasi:")
print(future_preds_scaled)

# Konversi kembali ke skala asli
future_preds = scaler.inverse_transform(future_preds_scaled)

# Konversi kembali ke skala asli dan ubah ke bilangan bulat
future_preds = scaler.inverse_transform(future_preds_scaled).astype(int)

# Cek nilai setelah inverse transform
print("Prediksi dalam skala asli:")
print(future_preds)

# Buat label bulan untuk prediksi
future_dates = pd.date_range(start=buku_200_copy['Bulan'].values[-1], periods=12, freq='M')

# Simpan hasil prediksi dalam DataFrame untuk analisis lebih lanjut
predictions_df = pd.DataFrame({'Bulan': future_dates, 'Prediksi': future_preds.flatten()})
print("Hasil prediksi dalam DataFrame:")
print(predictions_df)

# Gabungkan data aktual dan prediksi
combined_dates = np.concatenate([buku_200_copy['Bulan'].values, future_dates])
combined_values = np.concatenate([buku_200_copy['Jumlah_buku_dipinjam'].values, future_preds.flatten()])

# Visualisasi hasil prediksi dengan satu garis tetapi warna berbeda
plt.figure(figsize=(14, 8))

# Plot data aktual dengan warna biru
plt.plot(combined_dates[:len(buku_200_copy)], combined_values[:len(buku_200_copy)], color='blue', label='Actual Data')

# Plot data prediksi dengan warna merah (melanjutkan garis sebelumnya)
plt.plot(combined_dates[len(buku_200_copy)-1:], combined_values[len(buku_200_copy)-1:], color='red', label='CNN-GRU Forecast')

plt.title('Perbandingan Hasil Forecasting Peminjaman Buku')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Buku Dipinjam')
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Prediksi dalam skala normalisasi:
# [[0.1621181 ]
#  [0.16039239]
#  [0.1658891 ]
#  [0.16578907]
#  [0.169572  ]
#  [0.16635719]
#  [0.1698838 ]
#  [0.16508637]
#  [0.16423814]
#  [0.16290788]
#  [0.16105247]
#  [0.16078427]]
# Prediksi dalam skala asli:
# [[119]
#  [118]
#  [122]
#  [122]
#  [124]
#  [122]
#  [124]
#  [121]
#  [121]
#  [120]
#  [119]
#  [118]]
# Hasil prediksi dalam DataFrame:
#         Bulan  Prediksi
# 0  2024-12-31       119
# 1  2025-01-31       118
# 2  2025-02-28       122
# 3  2025-03-31       122
# 4  2025-04-30       124
# 5  2025-05-31       122
# 6  2025-06-30       124
# 7  2025-07-31       121
# 8  2025-08-31       121
# 9  2025-09-30       120
# 10 2025-10-31       119
# 11 2025-11-30       118
# C:\Users\asus\AppData\Local\Temp\ipykernel_2800\2311185865.py:35: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=buku_200_copy['Bulan'].values[-1], periods=12, freq='M')

# %% [markdown]
# # Data split 70:30

# %% [markdown]
# Hyperparameter Tunning

# %%
# Data awal
X_raw = buku_200_copy[['Jumlah_buku_dipinjam']].values

# Fungsi membuat data dengan timestep
def create_timestep_data(data, timestep):
    X, y = [], []
    for i in range(len(data) - timestep):
        X.append(data[i:i+timestep])
        y.append(data[i+timestep])
    return np.array(X), np.array(y)

# Grid Search Parameter
param_grid = {
    'timestep': [12, 24],
    'epochs': [50, 100, 170],
    'batch_size': [32, 64, 128],
    'gru_units': [10, 20, 100],
    'cnn_filters': [16, 32, 128],
}

# Inisialisasi variabel terbaik
best_rmse = float('inf')
best_params = None
results = []

# Iterasi seluruh kombinasi parameter
for params in ParameterGrid(param_grid):
    timestep = params['timestep']
    print(f"\nTesting combination: {params}")

    # Buat ulang data dengan timestep baru
    X, y = create_timestep_data(X_raw, timestep)

    # Split train-test (tanpa shuffle)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=False)

    # Reshape data agar sesuai dengan input model CNN-GRU
    X_train = X_train.reshape((X_train.shape[0], timestep, 1))
    X_test = X_test.reshape((X_test.shape[0], timestep, 1))

    # Normalisasi target
    scaler = MinMaxScaler()
    y_train_scaled = scaler.fit_transform(y_train.reshape(-1, 1))
    y_test_scaled = scaler.transform(y_test.reshape(-1, 1))

    # Bangun model CNN-GRU
    model = Sequential()

    # CNN Layer
    model.add(Conv1D(filters=params['cnn_filters'], kernel_size=1, activation='relu', input_shape=(timestep, 1)))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Flatten())  

    # Reshape sebelum masuk ke GRU
    model.add(Reshape((1, -1)))

    # GRU Layer
    model.add(GRU(params['gru_units'], activation='relu'))  
    model.add(Dropout(0.2))  

    # Output Layer
    model.add(Dense(1))

    # Compile model
    model.compile(optimizer='adam', loss='mean_squared_error')

    # Train model
    model.fit(X_train, y_train_scaled, epochs=params['epochs'], batch_size=params['batch_size'], verbose=0)
    
    # Evaluate model
    y_pred = model.predict(X_test)
    y_pred_inverse = scaler.inverse_transform(y_pred)
    y_test_inverse = scaler.inverse_transform(y_test_scaled)
    
    mse = mean_squared_error(y_test_inverse, y_pred_inverse)
    rmse = np.sqrt(mse)

    print(f"RMSE: {rmse}")

    # Simpan hasil tuning
    results.append((params, rmse))
    
    # Simpan kombinasi terbaik
    if rmse < best_rmse:
        best_rmse = rmse
        best_params = params

# Print hasil terbaik
print(f"\nBest RMSE: {best_rmse}")
print(f"Best parameters: {best_params}")

# Display seluruh hasil tuning
for res in results:
    print(f"Params: {res[0]} -> RMSE: {res[1]}")

# Simpan hasil tuning ke Excel
results_df = pd.DataFrame([
    {
        'timestep': r[0]['timestep'],
        'epochs': r[0]['epochs'],
        'batch_size': r[0]['batch_size'],
        'gru_units': r[0]['gru_units'],
        'cnn_filters': r[0]['cnn_filters'],
        'RMSE': r[1]
    }
    for r in results
])

# Simpan ke file Excel
results_df.to_excel("tuning buku_200 70,30.xlsx", index=False)
# Out:
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# RMSE: 208.02159089788037
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# RMSE: 101.07597543456733
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# RMSE: 92.84033605279427
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# RMSE: 94.8519142874289
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000020CFC42FEB0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# RMSE: 110.85019953367478
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000020CFBB1F400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# RMSE: 300.4568519068278
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# RMSE: 108.53659694697515
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# RMSE: 602.6698021732791
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# RMSE: 101.87816448972396
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# RMSE: 166.59798838277413
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# RMSE: 96.724880030042
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# RMSE: 508.8258129233954
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# RMSE: 75.66004913470607
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# RMSE: 84.05552553700282
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 541ms/step
# RMSE: 87.5275884968678
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# RMSE: 67.69892389676963
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# RMSE: 31.561935408967
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# RMSE: 85.13612066045951
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# RMSE: 78.5824562948041
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# RMSE: 87.23277833783537
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# RMSE: 32.15198339605206
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# RMSE: 94.59103434471676
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# RMSE: 30.0465113960586
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# RMSE: 316.20093514679985
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# RMSE: 99.37174356226284
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 76.98162799861475
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# RMSE: 84.689784640679
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# RMSE: 51.06405326175974
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# RMSE: 68.60506963720604
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# RMSE: 183.61341189849026
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# RMSE: 81.79695047341227
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# RMSE: 67.38438936253613
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# RMSE: 64.4172030323634
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# RMSE: 23.384365426877753
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# RMSE: 35.12144125888572
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# RMSE: 87.37889972849082
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# RMSE: 87.49601946443882
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# RMSE: 68.07408196098378
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# RMSE: 97.4476489106713
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# RMSE: 113.91108886149391
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# RMSE: 59.70650480152882
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# RMSE: 83.24737780800007
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# RMSE: 95.02487742577753
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# RMSE: 81.98544917562012
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# RMSE: 73.02002444593253
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# RMSE: 87.91756895335483
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# RMSE: 77.65377814182169
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# RMSE: 40.35879115640014
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# RMSE: 52.90112205679112
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# RMSE: 36.795030635281485
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# RMSE: 20.221264163305207
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# RMSE: 72.74237517333594
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# RMSE: 33.37420865389484
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# RMSE: 51.18777221987016
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# RMSE: 89.08261690381798
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# RMSE: 573.9738119072584
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# RMSE: 1064.9659685514018
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# RMSE: 637.3461969341054
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# RMSE: 129.35744273057284
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# RMSE: 1081.280701217879
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# RMSE: 86.2989512108246
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# RMSE: 88.90468061111555
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# RMSE: 170.91397363268192
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# RMSE: 86.27840812559357
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# RMSE: 100.34553102810975
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# RMSE: 622.4429057816617
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# RMSE: 64.12134989734231
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# RMSE: 53.734837001655016
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# RMSE: 141.00022596381297
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# RMSE: 107.70593556195679
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# RMSE: 210.9500509755226
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# RMSE: 57.74872816877067
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# RMSE: 93.86657613333827
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# RMSE: 610.792201262358
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# RMSE: 519.4768321378149
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# RMSE: 36.66917517334111
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# RMSE: 224.85234636688264
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# RMSE: 366.60372712014
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# RMSE: 89.79195416286196
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# RMSE: 80.60343667437527
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# RMSE: 290.7217176157
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# RMSE: 81.08882071683384
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# RMSE: 130.39932423996711
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# RMSE: 140.56120490970363
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ...
# Params: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 67.38438936253613
# Params: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 64.4172030323634
# Params: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 23.384365426877753
# Params: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 35.12144125888572
# Params: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 87.37889972849082
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 87.49601946443882
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 68.07408196098378
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 97.4476489106713
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 113.91108886149391
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 59.70650480152882
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 83.24737780800007
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 95.02487742577753
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 81.98544917562012
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 73.02002444593253
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 87.91756895335483
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 77.65377814182169
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 40.35879115640014
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 52.90112205679112
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 36.795030635281485
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 20.221264163305207
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 72.74237517333594
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 33.37420865389484
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 51.18777221987016
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 89.08261690381798
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 573.9738119072584
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 1064.9659685514018
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 637.3461969341054
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 129.35744273057284
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 1081.280701217879
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 86.2989512108246
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 88.90468061111555
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 170.91397363268192
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 86.27840812559357
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 100.34553102810975
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 622.4429057816617
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 64.12134989734231
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 53.734837001655016
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 141.00022596381297
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 107.70593556195679
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 210.9500509755226
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 57.74872816877067
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 93.86657613333827
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 610.792201262358
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 519.4768321378149
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 36.66917517334111
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 224.85234636688264
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 366.60372712014
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 89.79195416286196
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 80.60343667437527
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 290.7217176157
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 81.08882071683384
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 130.39932423996711
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 140.56120490970363
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 82.14080616356752
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 85.33347101198261
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 95.32236743350438
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 88.18566496420537
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 46.607407669719805
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 119.63630211972729
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 95.89528708852475
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 96.58438325501909
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 97.59620743836193
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 96.17690141704405
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 80.82771612182688
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 171.60607237202154
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 63.447949477036836
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 85.51600813001791
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 89.96312651987715
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 77.51564399414814
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 72.06413938267407
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 77.39018174148158
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 95.47107542777283
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 74.75301159844858
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 79.00042823292141
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 92.04710818352005
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 32.41147702567942
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 44.87696282970078
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 96.33886834039109
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 91.77322128187446
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 415.3339522651885
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 1357.759768683229
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 580.0953542838733
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 981.9957877083307
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 602.7342441395856
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 83.16916868167242
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 235.46392809363957
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 493.08847367153027
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 107.60609877355544
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 82.48953004505988
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 685.3583891464823
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 175.34741324902487
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 75.83857214604582
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 119.51069343179917
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 106.27327027866566
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 292.67625258164384
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 88.61910522266821
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 88.32348723662298
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 122.36906371403508
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 96.68443240041712
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 297.31371453535803
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 521.6390270689581
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 102.58259158131754
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 148.10447819164352
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 22.776961377530526
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 89.6859678180898
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 81.17784513316325
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 77.52684575290402
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 62.664209207605666
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 74.26602470430325
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 53.81687444470729
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 90.33396748972449
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 52.26009909679328
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 364.6483490804146
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 96.61939585412125
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 87.84192940619764
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 97.76415786522428
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 96.91154528392136
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 243.7055267646207
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 53.92935652511538
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 86.08861338850748
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 91.72511056232298
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 94.51951996315664
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 82.51410930558463
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 31.74145331497959
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 44.30144011564534
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 95.26434236899303
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 93.33411538539282
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 68.41412628242718
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 91.41242852075277
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 30.559940690779435
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 93.44363535047152

# %% [markdown]
# Model CNN-GRU

# %%
# Parameter window size
timestep = 12  # Menggunakan 6 bulan terakhir sebagai input

# Membentuk data input dengan sliding window
def create_sliding_window(data, timestep):
    X, y = [], []
    for i in range(len(data) - timestep):
        X.append(data[i:i+timestep])
        y.append(data[i+timestep])
    return np.array(X), np.array(y)

# Memisahkan fitur dan target
X = buku_200_copy[['Jumlah_buku_dipinjam']].values
y = buku_200_copy[['Jumlah_buku_dipinjam']].values

# Normalisasi data
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Membuat dataset sliding window
X_window, y_window = create_sliding_window(X_scaled, timestep)

# Split data menjadi train dan test (80% training, 20% testing)
split_idx = int(len(X_window) * 0.7)
X_train, X_test = X_window[:split_idx], X_window[split_idx:]
y_train, y_test = y_window[:split_idx], y_window[split_idx:]

# Reshape input menjadi tiga dimensi (samples, timesteps, features)
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Membangun Model CNN-GRU
model_cnn_gru = Sequential()

# Lapisan CNN
model_cnn_gru.add(Conv1D(filters=128, kernel_size=1, activation='relu', input_shape=(timestep, 1)))
model_cnn_gru.add(MaxPooling1D(pool_size=2))
model_cnn_gru.add(Flatten())

# Ubah kembali ke bentuk tiga dimensi untuk input ke GRU
model_cnn_gru.add(Reshape((1, -1)))

# Lapisan GRU setelah CNN
model_cnn_gru.add(GRU(20, activation='relu'))
model_cnn_gru.add(Dropout(0.2))

# Lapisan output
model_cnn_gru.add(Dense(1))

# Kompilasi model
model_cnn_gru.compile(optimizer='adam', loss='mean_squared_error')

# Latih model
history_model = model_cnn_gru.fit(X_train, y_train, epochs=170, batch_size=32)

# Prediksi pada data uji
y_pred_cnn_gru = model_cnn_gru.predict(X_test)

# Konversi kembali ke skala asli
y_pred_cnn_gru_inverse = scaler.inverse_transform(y_pred_cnn_gru)
y_test_inverse = scaler.inverse_transform(y_test)

# Evaluasi model
mse = mean_squared_error(y_test_inverse, y_pred_cnn_gru_inverse)
rmse = np.sqrt(mse)
mape = mean_absolute_percentage_error(y_test_inverse, y_pred_cnn_gru_inverse) * 100
mae = mean_absolute_error(y_test_inverse, y_pred_cnn_gru_inverse)

print(f"RMSE: {rmse}")
print(f"MAPE: {mape:.2f}%")

# Plot hasil model (data aktual vs prediksi)
plt.figure(figsize=(14, 6))
plt.plot(buku_200_copy['Bulan'][-len(y_test_inverse):], y_test_inverse, label='Actual', color='blue')
plt.plot(buku_200_copy['Bulan'][-len(y_pred_cnn_gru_inverse):], y_pred_cnn_gru_inverse, label='Predicted', linestyle='--', color='red')
plt.title('Perbandingan Hasil Model CNN-GRU pada Data Uji')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Buku Dipinjam')
plt.legend()
plt.show()

# plot loss
plt.figure(figsize=(14, 6))
plt.plot(history_model.history['loss'], label='Train Loss')
plt.title('Loss History')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/170
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.1449
# Epoch 2/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1375
# Epoch 3/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1117
# Epoch 4/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0821
# Epoch 5/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0540
# Epoch 6/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0436
# Epoch 7/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0343
# Epoch 8/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0310
# Epoch 9/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0457
# Epoch 10/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0439
# Epoch 11/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0320
# Epoch 12/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0297
# Epoch 13/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0308
# Epoch 14/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0283
# Epoch 15/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0381
# Epoch 16/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0272
# Epoch 17/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0264
# Epoch 18/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0304
# Epoch 19/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0373
# Epoch 20/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0201
# Epoch 21/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0246
# Epoch 22/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0234
# Epoch 23/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0313
# Epoch 24/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0182
# Epoch 25/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0154
# Epoch 26/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0199
# Epoch 27/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0291
# Epoch 28/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0203
# Epoch 29/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0215
# Epoch 30/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0183
# Epoch 31/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0201
# Epoch 32/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0217
# Epoch 33/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0160
# Epoch 34/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0155
# Epoch 35/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0245
# Epoch 36/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0186
# Epoch 37/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0228
# Epoch 38/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179
# Epoch 39/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0158
# Epoch 40/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0208
# Epoch 41/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0156
# Epoch 42/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0097
# Epoch 43/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0169
# Epoch 44/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0229
# Epoch 45/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0197
# Epoch 46/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0229
# Epoch 47/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0129
# Epoch 48/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0146
# Epoch 49/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0194
# Epoch 50/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0127
# Epoch 51/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0130
# Epoch 52/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0182
# Epoch 53/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0173
# Epoch 54/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0185
# Epoch 55/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0165
# Epoch 56/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0145
# Epoch 57/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0136
# Epoch 58/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0149
# Epoch 59/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0213
# Epoch 60/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0174
# Epoch 61/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0162
# Epoch 62/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0108
# Epoch 63/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0138
# Epoch 64/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0139
# Epoch 65/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0161
# Epoch 66/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0142
# Epoch 67/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0161
# Epoch 68/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0153
# Epoch 69/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0181
# Epoch 70/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0135
# Epoch 71/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0153
# Epoch 72/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0191
# Epoch 73/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0187
# Epoch 74/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0149
# Epoch 75/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0152
# Epoch 76/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0159
# Epoch 77/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0185
# Epoch 78/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0119
# Epoch 79/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0107
# Epoch 80/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0094
# Epoch 81/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0230
# Epoch 82/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0136
# Epoch 83/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0114
# Epoch 84/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0125
# Epoch 85/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0103
# Epoch 86/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0172
# Epoch 87/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0190
# Epoch 88/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0135
# Epoch 89/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0147
# Epoch 90/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0204
# Epoch 91/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0137
# Epoch 92/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0122
# Epoch 93/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0125
# Epoch 94/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0130
# Epoch 95/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0125
# Epoch 96/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0145
# Epoch 97/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0083
# Epoch 98/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0142
# Epoch 99/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0108
# Epoch 100/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0144
# Epoch 101/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0127
# Epoch 102/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0129
# Epoch 103/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0136
# Epoch 104/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0140
# Epoch 105/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0123
# Epoch 106/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0114
# Epoch 107/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0168
# Epoch 108/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0161
# Epoch 109/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0111
# Epoch 110/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0109
# Epoch 111/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0098
# Epoch 112/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0104
# Epoch 113/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0119
# Epoch 114/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0128
# Epoch 115/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0121
# Epoch 116/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0132
# Epoch 117/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0142
# Epoch 118/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0122
# Epoch 119/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0129
# Epoch 120/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0077
# Epoch 121/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0189
# Epoch 122/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0097
# Epoch 123/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0155
# Epoch 124/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0157
# Epoch 125/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0127
# Epoch 126/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0118
# Epoch 127/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0094
# Epoch 128/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0112
# Epoch 129/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0160
# Epoch 130/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0116
# Epoch 131/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0183
# Epoch 132/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0095
# Epoch 133/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0134
# Epoch 134/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0102
# Epoch 135/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0084
# Epoch 136/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0133
# Epoch 137/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0123
# Epoch 138/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0088
# Epoch 139/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0108
# Epoch 140/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0186
# Epoch 141/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0115
# Epoch 142/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0120
# Epoch 143/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0112
# Epoch 144/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0140
# Epoch 145/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0092
# Epoch 146/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0130
# Epoch 147/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0100
# Epoch 148/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0126
# Epoch 149/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0102
# Epoch 150/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0082
# Epoch 151/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0124
# Epoch 152/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0078
# Epoch 153/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0155
# Epoch 154/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0075
# Epoch 155/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0152
# Epoch 156/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0161
# Epoch 157/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0078
# Epoch 158/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0153
# Epoch 159/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0148
# Epoch 160/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0137
# Epoch 161/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0104
# Epoch 162/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0109
# Epoch 163/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0124
# Epoch 164/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0120
# Epoch 165/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0118
# Epoch 166/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0129
# Epoch 167/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0107
# Epoch 168/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0169
# Epoch 169/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0110
# Epoch 170/170
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0121
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# RMSE: 16.365670506005163
# MAPE: 13.45%

# %%
# Prediksi 12 bulan ke depan menggunakan sliding window
def predict_future(model, last_input, months=12):
    future_predictions = []
    current_input = last_input.copy()

    for _ in range(months):
        prediction = model.predict(current_input.reshape((1, timestep, 1)))
        future_predictions.append(prediction[0, 0])
        
        # Geser input window dengan menambahkan prediksi terbaru
        current_input = np.roll(current_input, -1)
        current_input[-1] = prediction[0, 0]

    return np.array(future_predictions).reshape(-1, 1)

# Gunakan data terakhir sebagai input awal
last_input = X_scaled[-timestep:]
future_preds_scaled = predict_future(model_cnn_gru, last_input, months=12)

# Cek nilai sebelum inverse transform
print("Prediksi dalam skala normalisasi:")
print(future_preds_scaled)

# Konversi kembali ke skala asli
future_preds = scaler.inverse_transform(future_preds_scaled)

# Konversi kembali ke skala asli dan ubah ke bilangan bulat
future_preds = scaler.inverse_transform(future_preds_scaled).astype(int)

# Cek nilai setelah inverse transform
print("Prediksi dalam skala asli:")
print(future_preds)

# Buat label bulan untuk prediksi
future_dates = pd.date_range(start=buku_200_copy['Bulan'].values[-1], periods=12, freq='M')

# Simpan hasil prediksi dalam DataFrame untuk analisis lebih lanjut
predictions_df = pd.DataFrame({'Bulan': future_dates, 'Prediksi': future_preds.flatten()})
print("Hasil prediksi dalam DataFrame:")
print(predictions_df)

# Gabungkan data aktual dan prediksi
combined_dates = np.concatenate([buku_200_copy['Bulan'].values, future_dates])
combined_values = np.concatenate([buku_200_copy['Jumlah_buku_dipinjam'].values, future_preds.flatten()])

# Visualisasi hasil prediksi dengan satu garis tetapi warna berbeda
plt.figure(figsize=(14, 8))

# Plot data aktual dengan warna biru
plt.plot(combined_dates[:len(buku_200_copy)], combined_values[:len(buku_200_copy)], color='blue', label='Actual Data')

# Plot data prediksi dengan warna merah (melanjutkan garis sebelumnya)
plt.plot(combined_dates[len(buku_200_copy)-1:], combined_values[len(buku_200_copy)-1:], color='red', label='CNN-GRU Forecast')
plt.xticks(fontsize=29)
plt.yticks(fontsize=35)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Prediksi dalam skala normalisasi:
# [[0.15719928]
#  [0.15059455]
#  [0.15119438]
#  [0.145487  ]
#  [0.14255881]
#  [0.13956337]
#  [0.13930117]
#  [0.13479969]
#  [0.13700591]
#  [0.13949546]
#  [0.134657  ]
#  [0.13436647]]
# Prediksi dalam skala asli:
# [[116]
#  [112]
#  [112]
#  [108]
#  [106]
#  [104]
#  [104]
#  [101]
#  [102]
#  [104]
#  [101]
#  [101]]
# Hasil prediksi dalam DataFrame:
#         Bulan  Prediksi
# 0  2024-12-31       116
# 1  2025-01-31       112
# 2  2025-02-28       112
# 3  2025-03-31       108
# 4  2025-04-30       106
# 5  2025-05-31       104
# 6  2025-06-30       104
# 7  2025-07-31       101
# 8  2025-08-31       102
# 9  2025-09-30       104
# 10 2025-10-31       101
# 11 2025-11-30       101
# C:\Users\asus\AppData\Local\Temp\ipykernel_22404\3842377768.py:35: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=buku_200_copy['Bulan'].values[-1], periods=12, freq='M')

# %% [markdown]
# # Data split 80:20

# %% [markdown]
# Hyperparameter Tunning

# %%
# Data awal
X_raw = buku_200_copy[['Jumlah_buku_dipinjam']].values

# Fungsi membuat data dengan timestep
def create_timestep_data(data, timestep):
    X, y = [], []
    for i in range(len(data) - timestep):
        X.append(data[i:i+timestep])
        y.append(data[i+timestep])
    return np.array(X), np.array(y)

# Grid Search Parameter
param_grid = {
    'timestep': [12, 24],
    'epochs': [50, 100, 170],
    'batch_size': [32, 64, 128],
    'gru_units': [10, 20, 100],
    'cnn_filters': [16, 32, 128],
}

# Inisialisasi variabel terbaik
best_rmse = float('inf')
best_params = None
results = []

# Iterasi seluruh kombinasi parameter
for params in ParameterGrid(param_grid):
    timestep = params['timestep']
    print(f"\nTesting combination: {params}")

    # Buat ulang data dengan timestep baru
    X, y = create_timestep_data(X_raw, timestep)

    # Split train-test (tanpa shuffle)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

    # Reshape data agar sesuai dengan input model CNN-GRU
    X_train = X_train.reshape((X_train.shape[0], timestep, 1))
    X_test = X_test.reshape((X_test.shape[0], timestep, 1))

    # Normalisasi target
    scaler = MinMaxScaler()
    y_train_scaled = scaler.fit_transform(y_train.reshape(-1, 1))
    y_test_scaled = scaler.transform(y_test.reshape(-1, 1))

    # Bangun model CNN-GRU
    model = Sequential()

    # CNN Layer
    model.add(Conv1D(filters=params['cnn_filters'], kernel_size=1, activation='relu', input_shape=(timestep, 1)))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Flatten())  

    # Reshape sebelum masuk ke GRU
    model.add(Reshape((1, -1)))

    # GRU Layer
    model.add(GRU(params['gru_units'], activation='relu'))  
    model.add(Dropout(0.2))  

    # Output Layer
    model.add(Dense(1))

    # Compile model
    model.compile(optimizer='adam', loss='mean_squared_error')

    # Train model
    model.fit(X_train, y_train_scaled, epochs=params['epochs'], batch_size=params['batch_size'], verbose=0)
    
    # Evaluate model
    y_pred = model.predict(X_test)
    y_pred_inverse = scaler.inverse_transform(y_pred)
    y_test_inverse = scaler.inverse_transform(y_test_scaled)
    
    mse = mean_squared_error(y_test_inverse, y_pred_inverse)
    rmse = np.sqrt(mse)

    print(f"RMSE: {rmse}")

    # Simpan hasil tuning
    results.append((params, rmse))
    
    # Simpan kombinasi terbaik
    if rmse < best_rmse:
        best_rmse = rmse
        best_params = params

# Print hasil terbaik
print(f"\nBest RMSE: {best_rmse}")
print(f"Best parameters: {best_params}")

# Display seluruh hasil tuning
for res in results:
    print(f"Params: {res[0]} -> RMSE: {res[1]}")

# Simpan hasil tuning ke Excel
results_df = pd.DataFrame([
    {
        'timestep': r[0]['timestep'],
        'epochs': r[0]['epochs'],
        'batch_size': r[0]['batch_size'],
        'gru_units': r[0]['gru_units'],
        'cnn_filters': r[0]['cnn_filters'],
        'RMSE': r[1]
    }
    for r in results
])

# Simpan ke file Excel
results_df.to_excel("tuning buku_200 80,20.xlsx", index=False)
# Out:
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 329.3999141878197
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# RMSE: 84.85356849283657
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 27.089506905500627
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# RMSE: 86.40422870721581
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# RMSE: 284.4042708951372
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 109.51210927224636
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# RMSE: 115.65549290950166
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# RMSE: 94.55910762875007
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 70.52606772028005
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# RMSE: 76.55825055277751
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# RMSE: 127.20591475683253
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# RMSE: 58.82089939411906
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# RMSE: 21.792217957898707
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# RMSE: 49.87215256339252
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 108.19683709649371
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# RMSE: 54.72938846759727
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# RMSE: 46.63494251387323
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# RMSE: 67.13791052019742
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 35.500181759794614
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 87.8952838476491
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 71.62083757087107
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 92.23386082062856
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 54.89457429453281
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# RMSE: 623.4387780976081
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 78.50750592473779
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# RMSE: 76.98951495261306
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# RMSE: 90.38737230542561
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 78.7557336744038
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# RMSE: 39.909116235312524
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 67.62061293005358
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 88.25113043238676
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# RMSE: 82.53528860086749
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# RMSE: 26.884519321591423
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 78.30458551191117
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# RMSE: 46.50588721642222
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# RMSE: 43.921077913479586
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 85.05842687008087
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 78.25714144728411
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 85.8143259261734
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 88.35494234346066
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# RMSE: 53.66491307341694
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 179.5842645203382
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# RMSE: 78.28782760063751
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# RMSE: 86.40724597267597
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 66.62872355143803
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 80.74978586239003
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# RMSE: 51.91704121086659
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 88.70100170905326
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# RMSE: 22.499798735087687
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 37.04764389725241
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 22.308435466683406
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 63.62186725407123
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# RMSE: 23.1464690436214
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# RMSE: 89.21307133598167
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# RMSE: 165.62996284769582
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# RMSE: 966.4441949585243
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 689.0687162712087
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# RMSE: 96.25661068820737
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# RMSE: 760.5139309192265
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 466.0563012193578
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 103.66177068131077
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 32.41602536878954
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# RMSE: 232.66216003498218
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 132.09234698027169
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# RMSE: 143.67232444805822
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 279.43452661614924
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 69.58765785484489
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 87.34206711639527
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 94.77143365880188
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# RMSE: 87.1739264816177
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 37.406938605345516
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 120.08222433321144
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# RMSE: 83.19527049532786
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# RMSE: 90.98054072945312
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# RMSE: 93.06588199762187
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 89.0887580417295
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# RMSE: 170.4675112576305
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# RMSE: 341.18929795292604
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# RMSE: 78.20325551707927
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# RMSE: 66.13456513422442
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# RMSE: 125.93068391391556
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# RMSE: 85.65206584416326
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# RMSE: 102.00692977671618
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# RMSE: 85.98522556560788
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# RMSE: 82.80964698309958
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# RMSE: 50.79665679745541
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# RMSE: 50.12685510793314
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 24}
# ...
# Params: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 82.53528860086749
# Params: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 26.884519321591423
# Params: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 78.30458551191117
# Params: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 46.50588721642222
# Params: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 43.921077913479586
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 85.05842687008087
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 78.25714144728411
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 85.8143259261734
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 88.35494234346066
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 53.66491307341694
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 179.5842645203382
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 78.28782760063751
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 86.40724597267597
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 66.62872355143803
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 80.74978586239003
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 51.91704121086659
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 88.70100170905326
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 22.499798735087687
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 37.04764389725241
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 22.308435466683406
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 63.62186725407123
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 23.1464690436214
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 89.21307133598167
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 165.62996284769582
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 966.4441949585243
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 689.0687162712087
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 96.25661068820737
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 760.5139309192265
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 466.0563012193578
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 103.66177068131077
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 32.41602536878954
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 232.66216003498218
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 132.09234698027169
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 143.67232444805822
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 279.43452661614924
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 69.58765785484489
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 87.34206711639527
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 94.77143365880188
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 87.1739264816177
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 37.406938605345516
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 120.08222433321144
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 83.19527049532786
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 90.98054072945312
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 93.06588199762187
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 89.0887580417295
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 170.4675112576305
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 341.18929795292604
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 78.20325551707927
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 66.13456513422442
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 125.93068391391556
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 85.65206584416326
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 102.00692977671618
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 85.98522556560788
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 82.80964698309958
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 50.79665679745541
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 50.12685510793314
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 52.63797836682203
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 74.93889434809473
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 274.63631170316404
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 91.65436271252449
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 88.26146142989616
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 86.78199191930446
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 91.99625283912549
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 71.3294833128074
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 455.79098229926836
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 82.62888540164055
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 82.50825732571131
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 27.123816446923275
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 88.93293451701683
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 34.24901084591372
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 81.46395876909206
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 63.93135814934977
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 85.76159494684849
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 55.63182681853534
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 83.12416371911998
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 28.824139016393023
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 89.53345603104539
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 80.24788826300625
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 85.85643605950258
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 551.2376360797069
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 93.90853375735765
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 330.4767273922327
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 577.8447334864705
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 73.3466809539562
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 75.54479528446093
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 85.89862816892109
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 508.5806334616522
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 221.1310863372799
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 50.85062732853054
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 63.48852554129232
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 73.57817969398302
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 292.18689780187157
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 82.52446593307253
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 121.06410824094259
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 77.64208610279505
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 66.99033805894481
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 92.88189659165273
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 471.80386660457293
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 92.98303412566464
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 367.9236556767042
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 312.5378402813758
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 43.6641869067787
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 90.16322932641299
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 69.00056305943842
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 42.60877142451431
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 233.8948069735664
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 48.33318922154596
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 54.298860877670734
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 86.85398606268396
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 57.65567314771205
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 81.41994253321214
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 113.7525526271131
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 91.73312807786627
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 78.42344156998378
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 87.80284069306464
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 90.3870443020683
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 89.13578004425277
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 107.7277448356977
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 51.35635391298867
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 79.32507591104263
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 86.5498674040708
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 91.89452070234245
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 89.69798420381241
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 26.28901054909292
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 27.85464955776952
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 27.621649731630896
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 54.21097057083064
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 23.61957331514331
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 83.30146509749036
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 31.033864842610594
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 47.51674385790083

# %% [markdown]
# Model CNN-GRU

# %%
# Parameter window size
timestep = 12  # Menggunakan 6 bulan terakhir sebagai input

# Membentuk data input dengan sliding window
def create_sliding_window(data, timestep):
    X, y = [], []
    for i in range(len(data) - timestep):
        X.append(data[i:i+timestep])
        y.append(data[i+timestep])
    return np.array(X), np.array(y)

# Memisahkan fitur dan target
X = buku_200_copy[['Jumlah_buku_dipinjam']].values
y = buku_200_copy[['Jumlah_buku_dipinjam']].values

# Normalisasi data
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Membuat dataset sliding window
X_window, y_window = create_sliding_window(X_scaled, timestep)

# Split data menjadi train dan test (80% training, 20% testing)
split_idx = int(len(X_window) * 0.8)
X_train, X_test = X_window[:split_idx], X_window[split_idx:]
y_train, y_test = y_window[:split_idx], y_window[split_idx:]

# Reshape input menjadi tiga dimensi (samples, timesteps, features)
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Membangun Model CNN-GRU
model_cnn_gru = Sequential()

# Lapisan CNN
model_cnn_gru.add(Conv1D(filters=16, kernel_size=1, activation='relu', input_shape=(timestep, 1)))
model_cnn_gru.add(MaxPooling1D(pool_size=2))
model_cnn_gru.add(Flatten())

# Ubah kembali ke bentuk tiga dimensi untuk input ke GRU
model_cnn_gru.add(Reshape((1, -1)))

# Lapisan GRU setelah CNN
model_cnn_gru.add(GRU(10, activation='relu'))
model_cnn_gru.add(Dropout(0.2))

# Lapisan output
model_cnn_gru.add(Dense(1))

# Kompilasi model
model_cnn_gru.compile(optimizer='adam', loss='mean_squared_error')

# Latih model
history_model = model_cnn_gru.fit(X_train, y_train, epochs=170, batch_size=32)

# Prediksi pada data uji
y_pred_cnn_gru = model_cnn_gru.predict(X_test)

# Konversi kembali ke skala asli
y_pred_cnn_gru_inverse = scaler.inverse_transform(y_pred_cnn_gru)
y_test_inverse = scaler.inverse_transform(y_test)

# Evaluasi model
mse = mean_squared_error(y_test_inverse, y_pred_cnn_gru_inverse)
rmse = np.sqrt(mse)
mape = mean_absolute_percentage_error(y_test_inverse, y_pred_cnn_gru_inverse) * 100
mae = mean_absolute_error(y_test_inverse, y_pred_cnn_gru_inverse)

print(f"RMSE: {rmse}")
print(f"MAPE: {mape:.2f}%")

# Plot hasil model (data aktual vs prediksi)
plt.figure(figsize=(14, 6))
plt.plot(buku_200_copy['Bulan'][-len(y_test_inverse):], y_test_inverse, label='Actual', color='blue')
plt.plot(buku_200_copy['Bulan'][-len(y_pred_cnn_gru_inverse):], y_pred_cnn_gru_inverse, label='Predicted', linestyle='--', color='red')
plt.title('Perbandingan Hasil Model CNN-GRU pada Data Uji')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Buku Dipinjam')
plt.legend()
plt.show()

# plot loss
plt.figure(figsize=(14, 6))
plt.plot(history_model.history['loss'], label='Train Loss')
plt.title('Loss History')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/170
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.1582
# Epoch 2/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1388
# Epoch 3/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1428
# Epoch 4/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1232
# Epoch 5/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1102
# Epoch 6/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1056
# Epoch 7/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0960
# Epoch 8/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0765
# Epoch 9/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0601
# Epoch 10/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0570
# Epoch 11/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0439
# Epoch 12/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0330
# Epoch 13/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0332
# Epoch 14/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0237
# Epoch 15/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0303
# Epoch 16/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0260
# Epoch 17/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0378
# Epoch 18/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0284
# Epoch 19/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0308
# Epoch 20/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0305
# Epoch 21/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0331
# Epoch 22/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0274
# Epoch 23/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0272
# Epoch 24/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0247
# Epoch 25/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0462
# Epoch 26/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0266
# Epoch 27/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0319
# Epoch 28/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0316
# Epoch 29/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0249
# Epoch 30/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0285
# Epoch 31/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0312
# Epoch 32/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0312
# Epoch 33/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0190
# Epoch 34/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0246
# Epoch 35/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0209
# Epoch 36/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0173
# Epoch 37/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0219
# Epoch 38/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0233
# Epoch 39/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0227
# Epoch 40/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0172
# Epoch 41/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0211
# Epoch 42/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0245
# Epoch 43/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0218
# Epoch 44/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0206
# Epoch 45/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0210
# Epoch 46/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0172
# Epoch 47/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0215
# Epoch 48/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0289
# Epoch 49/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0222
# Epoch 50/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0268
# Epoch 51/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0226
# Epoch 52/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0283
# Epoch 53/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0349
# Epoch 54/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0213
# Epoch 55/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0208
# Epoch 56/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0163
# Epoch 57/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0246
# Epoch 58/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0166
# Epoch 59/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0228
# Epoch 60/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0203
# Epoch 61/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0158
# Epoch 62/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0199
# Epoch 63/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0215
# Epoch 64/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0140
# Epoch 65/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0165
# Epoch 66/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0221
# Epoch 67/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0202
# Epoch 68/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0188
# Epoch 69/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0167
# Epoch 70/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0223
# Epoch 71/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0142
# Epoch 72/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0150
# Epoch 73/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0223
# Epoch 74/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0146
# Epoch 75/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0153
# Epoch 76/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0172
# Epoch 77/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0196
# Epoch 78/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0180
# Epoch 79/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0173
# Epoch 80/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0175
# Epoch 81/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0196
# Epoch 82/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0140
# Epoch 83/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0163
# Epoch 84/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0137
# Epoch 85/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0223
# Epoch 86/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0163
# Epoch 87/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0234
# Epoch 88/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0175
# Epoch 89/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0140
# Epoch 90/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0172
# Epoch 91/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0193
# Epoch 92/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0124
# Epoch 93/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0159
# Epoch 94/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0153
# Epoch 95/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0190
# Epoch 96/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0187
# Epoch 97/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0147
# Epoch 98/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0197
# Epoch 99/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0163
# Epoch 100/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0146
# Epoch 101/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0132
# Epoch 102/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0139
# Epoch 103/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0189
# Epoch 104/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0192
# Epoch 105/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0172
# Epoch 106/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0182
# Epoch 107/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0123
# Epoch 108/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0144
# Epoch 109/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0098
# Epoch 110/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0120
# Epoch 111/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0163
# Epoch 112/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0207
# Epoch 113/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0177
# Epoch 114/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0187
# Epoch 115/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0186
# Epoch 116/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0222
# Epoch 117/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0161
# Epoch 118/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0157
# Epoch 119/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0138
# Epoch 120/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0178
# Epoch 121/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0151
# Epoch 122/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0149
# Epoch 123/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0159
# Epoch 124/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0145
# Epoch 125/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0102
# Epoch 126/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0120
# Epoch 127/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0169
# Epoch 128/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0139
# Epoch 129/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0129
# Epoch 130/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0148
# Epoch 131/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0181
# Epoch 132/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0260
# Epoch 133/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0114
# Epoch 134/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0183
# Epoch 135/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0161
# Epoch 136/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0168
# Epoch 137/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0119
# Epoch 138/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0106
# Epoch 139/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0113
# Epoch 140/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0114
# Epoch 141/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0167
# Epoch 142/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0108
# Epoch 143/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0212
# Epoch 144/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0165
# Epoch 145/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0166
# Epoch 146/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0147
# Epoch 147/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0215
# Epoch 148/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0122
# Epoch 149/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0172
# Epoch 150/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0204
# Epoch 151/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0152
# Epoch 152/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0128
# Epoch 153/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0158
# Epoch 154/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0122
# Epoch 155/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0125
# Epoch 156/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0141
# Epoch 157/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0161
# Epoch 158/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0177
# Epoch 159/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0127
# Epoch 160/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0110
# Epoch 161/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0123
# Epoch 162/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0135
# Epoch 163/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0169
# Epoch 164/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0162
# Epoch 165/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0124
# Epoch 166/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0157
# Epoch 167/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0157
# Epoch 168/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0122
# Epoch 169/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0162
# Epoch 170/170
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0177
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 19.95305467115921
# MAPE: 17.59%

# %%
# Prediksi 12 bulan ke depan menggunakan sliding window
def predict_future(model, last_input, months=12):
    future_predictions = []
    current_input = last_input.copy()

    for _ in range(months):
        prediction = model.predict(current_input.reshape((1, timestep, 1)))
        future_predictions.append(prediction[0, 0])
        
        # Geser input window dengan menambahkan prediksi terbaru
        current_input = np.roll(current_input, -1)
        current_input[-1] = prediction[0, 0]

    return np.array(future_predictions).reshape(-1, 1)

# Gunakan data terakhir sebagai input awal
last_input = X_scaled[-timestep:]
future_preds_scaled = predict_future(model_cnn_gru, last_input, months=12)

# Cek nilai sebelum inverse transform
print("Prediksi dalam skala normalisasi:")
print(future_preds_scaled)

# Konversi kembali ke skala asli
future_preds = scaler.inverse_transform(future_preds_scaled)

# Konversi kembali ke skala asli dan ubah ke bilangan bulat
future_preds = scaler.inverse_transform(future_preds_scaled).astype(int)

# Cek nilai setelah inverse transform
print("Prediksi dalam skala asli:")
print(future_preds)

# Buat label bulan untuk prediksi
future_dates = pd.date_range(start=buku_200_copy['Bulan'].values[-1], periods=12, freq='M')

# Simpan hasil prediksi dalam DataFrame untuk analisis lebih lanjut
predictions_df = pd.DataFrame({'Bulan': future_dates, 'Prediksi': future_preds.flatten()})
print("Hasil prediksi dalam DataFrame:")
print(predictions_df)

# Gabungkan data aktual dan prediksi
combined_dates = np.concatenate([buku_200_copy['Bulan'].values, future_dates])
combined_values = np.concatenate([buku_200_copy['Jumlah_buku_dipinjam'].values, future_preds.flatten()])

# Visualisasi hasil prediksi dengan satu garis tetapi warna berbeda
plt.figure(figsize=(14, 8))

# Plot data aktual dengan warna biru
plt.plot(combined_dates[:len(buku_200_copy)], combined_values[:len(buku_200_copy)], color='blue', label='Actual Data')

# Plot data prediksi dengan warna merah (melanjutkan garis sebelumnya)
plt.plot(combined_dates[len(buku_200_copy)-1:], combined_values[len(buku_200_copy)-1:], color='red', label='CNN-GRU Forecast')

plt.title('Perbandingan Hasil Forecasting Peminjaman Buku')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Buku Dipinjam')
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Prediksi dalam skala normalisasi:
# [[0.15766081]
#  [0.14622742]
#  [0.14672582]
#  [0.13776219]
#  [0.13787645]
#  [0.12889603]
#  [0.13577935]
#  [0.13402686]
#  [0.1308144 ]
#  [0.13407023]
#  [0.12647678]
#  [0.12637609]]
# Prediksi dalam skala asli:
# [[116]
#  [109]
#  [109]
#  [103]
#  [103]
#  [ 97]
#  [102]
#  [100]
#  [ 98]
#  [100]
#  [ 95]
#  [ 95]]
# Hasil prediksi dalam DataFrame:
#         Bulan  Prediksi
# 0  2024-12-31       116
# 1  2025-01-31       109
# 2  2025-02-28       109
# 3  2025-03-31       103
# 4  2025-04-30       103
# 5  2025-05-31        97
# 6  2025-06-30       102
# 7  2025-07-31       100
# 8  2025-08-31        98
# 9  2025-09-30       100
# 10 2025-10-31        95
# 11 2025-11-30        95
# C:\Users\asus\AppData\Local\Temp\ipykernel_19504\2311185865.py:35: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=buku_200_copy['Bulan'].values[-1], periods=12, freq='M')
