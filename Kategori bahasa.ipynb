# %% [markdown]
# # Peminjaman buku kategori bahasa

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import random
import altair as alt
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Reshape, GRU, Dense, Dropout, TimeDistributed
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.model_selection import ParameterGrid
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dropout
from bayes_opt import BayesianOptimization
from itertools import product

# %% [markdown]
# Read Dataset

# %%
buku_400 = pd.read_csv('D:\\KuliYeah\\Season 7\\Arc Skripsi\\forecasting\\buku_400.csv')
buku_400['Bulan'] = pd.to_datetime(buku_400['Bulan'], format='%m/%y')

# %%
buku_400.plot(x='Bulan', y='Jumlah_buku_dipinjam', kind='line')
plt.title('Jumlah Peminjaman Buku')
plt.xlabel('Tanggal')
plt.ylabel('Jumlah Peminjaman')
plt.show()

# %% [markdown]
# IQR

# %%
# Menghitung Q1, Q3 dan IQR
Q1 = buku_400['Jumlah_buku_dipinjam'].quantile(0.25)
Q3 = buku_400['Jumlah_buku_dipinjam'].quantile(0.75)
IQR = Q3 - Q1

# Batas bawah dan atas untuk outlier
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
buku_400
outliers_000 = buku_400[(buku_400['Jumlah_buku_dipinjam'] < lower_bound) | (buku_400['Jumlah_buku_dipinjam'] > upper_bound)]

print(outliers_000)
# Menampilkan batas bawah dan atas
print(f"Batas bawah: {lower_bound}")
print(f"Batas atas: {upper_bound}")

plt.figure(figsize=(8, 6))
sns.boxplot(x=buku_400['Jumlah_buku_dipinjam'])
plt.xlabel('Jumlah Peminjaman')
plt.ylabel('Jumlah Buku')
# Out:
#         Bulan  Jumlah_buku_dipinjam
# 26 2019-03-01                   247
# 32 2019-09-01                   257
# Batas bawah: -79.125
# Batas atas: 171.875
# Text(0, 0.5, 'Jumlah Buku')

# %% [markdown]
# Hyperparameter Tuning

# %%
# Rentang hyperparameter
window_sizes = [3, 8, 9]  # Contoh rentang window size
tolerances = [0.5, 1, 2, 2.5, 3]  # Contoh rentang tolerance

# Buat grid kombinasi hyperparameter
grid = list(product(window_sizes, tolerances))

# Simpan hasil tuning
results = []

for window_size, tolerance in grid:
    for tolerance in tolerances:
        buku_400_copy = buku_400.copy()  # Buat salinan data asli agar tidak merusak data asli

        # Rolling median dan rolling std
        buku_400_copy['rolling_median'] = buku_400_copy['Jumlah_buku_dipinjam'].rolling(window=window_size, center=True).median()
        buku_400_copy['rolling_std'] = buku_400_copy['Jumlah_buku_dipinjam'].rolling(window=window_size, center=True).std()

        # Batas atas dan bawah
        upper_bound = buku_400_copy['rolling_median'] + tolerance * buku_400_copy['rolling_std']
        lower_bound = buku_400_copy['rolling_median'] - tolerance * buku_400_copy['rolling_std']

        # Deteksi ou    tlier awal
        detected_outliers = (buku_400_copy['Jumlah_buku_dipinjam'] > upper_bound) | \
                            (buku_400_copy['Jumlah_buku_dipinjam'] < lower_bound)

        # Ganti outlier dengan rolling median
        buku_400_cleaned = buku_400_copy['Jumlah_buku_dipinjam'].copy()
        detected_outliers = (buku_400_copy['Jumlah_buku_dipinjam'] > upper_bound) | \
                            (buku_400_copy['Jumlah_buku_dipinjam'] < lower_bound)
        buku_400_cleaned[detected_outliers] = buku_400_copy['rolling_median'][detected_outliers]


        # Forecasting (contoh dummy prediksi)
        y_actual = buku_400_cleaned[10:]  # Data aktual (tes)
        y_pred = buku_400_cleaned.shift(1)[10:]  # Dummy prediksi

        # Hitung metrik evaluasi
        mape = mean_absolute_percentage_error(y_actual, y_pred)
        rmse = np.sqrt(mean_squared_error(y_actual, y_pred))

        # Simpan hasil
        results.append({
            'window_size': window_size,
            'tolerance': tolerance,
            'mape': mape,
            'rmse': rmse
        })

# Analisis hasil
results_df = pd.DataFrame(results)
best_result = results_df.sort_values(by='rmse').iloc[0]
print("Kombinasi terbaik berdasarkan MAPE & RMSE: ")
print(best_result)
# Tampilkan semua hasil tuning dari grid search
print("\nSeluruh hasil kombinasi hyperparameter rolling window median:")
for res in results:
    print(f"window_size: {res['window_size']}, Tolerance: {res['tolerance']} -> RMSE: {res['rmse']:.3f}")
# Simpan hasil grid search ke file Excel
results_df.to_excel("rwm buku_400.xlsx", index=False)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_21728\1070927692.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 42.   48.5  54.5  70.   85.   90.   70.   54.5  45.5  61.   66.   66.
#   52.5 108.5 122.  123.  126.  134.  137.5   0.    9.5   5.   19.5  25.
#   20.5  20.5  26.5  24.5  25.   27.   31.   36.5  31.   30.5  30.   24.
#   15.5  15.5  17.5  16.   19.   18.   15.   11.5  13.   16.5  16.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_400_cleaned[detected_outliers] = buku_400_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_21728\1070927692.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 48.5  54.5  70.   90.   54.5  52.5 123.  134.  137.5   0.    9.5   5.
#   20.5  20.5  25.   31.   15.5  16.   18.   13.   16.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_400_cleaned[detected_outliers] = buku_400_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_21728\1070927692.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[123.    0.    5.   15.5  16. ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_400_cleaned[detected_outliers] = buku_400_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_21728\1070927692.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 42.   48.5  54.5  70.   85.   90.   70.   54.5  45.5  61.   66.   66.
#   52.5 108.5 122.  123.  126.  134.  137.5   0.    9.5   5.   19.5  25.
#   20.5  20.5  26.5  24.5  25.   27.   31.   36.5  31.   30.5  30.   24.
#   15.5  15.5  17.5  16.   19.   18.   15.   11.5  13.   16.5  16.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_400_cleaned[detected_outliers] = buku_400_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_21728\1070927692.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 48.5  54.5  70.   90.   54.5  52.5 123.  134.  137.5   0.    9.5   5.
#   20.5  20.5  25.   31.   15.5  16.   18.   13.   16.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_400_cleaned[detected_outliers] = buku_400_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_21728\1070927692.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[123.    0.    5.   15.5  16. ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_400_cleaned[detected_outliers] = buku_400_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_21728\1070927692.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 42.   48.5  54.5  70.   85.   90.   70.   54.5  45.5  61.   66.   66.
#   52.5 108.5 122.  123.  126.  134.  137.5   0.    9.5   5.   19.5  25.
#   20.5  20.5  26.5  24.5  25.   27.   31.   36.5  31.   30.5  30.   24.
#   15.5  15.5  17.5  16.   19.   18.   15.   11.5  13.   16.5  16.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_400_cleaned[detected_outliers] = buku_400_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_21728\1070927692.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 48.5  54.5  70.   90.   54.5  52.5 123.  134.  137.5   0.    9.5   5.
#   20.5  20.5  25.   31.   15.5  16.   18.   13.   16.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_400_cleaned[detected_outliers] = buku_400_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_21728\1070927692.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[123.    0.    5.   15.5  16. ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_400_cleaned[detected_outliers] = buku_400_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_21728\1070927692.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 42.   48.5  54.5  70.   85.   90.   70.   54.5  45.5  61.   66.   66.
#   52.5 108.5 122.  123.  126.  134.  137.5   0.    9.5   5.   19.5  25.
#   20.5  20.5  26.5  24.5  25.   27.   31.   36.5  31.   30.5  30.   24.
#   15.5  15.5  17.5  16.   19.   18.   15.   11.5  13.   16.5  16.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_400_cleaned[detected_outliers] = buku_400_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_21728\1070927692.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 48.5  54.5  70.   90.   54.5  52.5 123.  134.  137.5   0.    9.5   5.
#   20.5  20.5  25.   31.   15.5  16.   18.   13.   16.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_400_cleaned[detected_outliers] = buku_400_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_21728\1070927692.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[123.    0.    5.   15.5  16. ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_400_cleaned[detected_outliers] = buku_400_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_21728\1070927692.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 42.   48.5  54.5  70.   85.   90.   70.   54.5  45.5  61.   66.   66.
#   52.5 108.5 122.  123.  126.  134.  137.5   0.    9.5   5.   19.5  25.
#   20.5  20.5  26.5  24.5  25.   27.   31.   36.5  31.   30.5  30.   24.
#   15.5  15.5  17.5  16.   19.   18.   15.   11.5  13.   16.5  16.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_400_cleaned[detected_outliers] = buku_400_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_21728\1070927692.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 48.5  54.5  70.   90.   54.5  52.5 123.  134.  137.5   0.    9.5   5.
#   20.5  20.5  25.   31.   15.5  16.   18.   13.   16.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_400_cleaned[detected_outliers] = buku_400_copy['rolling_median'][detected_outliers]
# C:\Users\asus\AppData\Local\Temp\ipykernel_21728\1070927692.py:31: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[123.    0.    5.   15.5  16. ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_400_cleaned[detected_outliers] = buku_400_copy['rolling_median'][detected_outliers]
# Kombinasi terbaik berdasarkan MAPE & RMSE:
# window_size    8.000000e+00
# tolerance      5.000000e-01
# mape           1.518656e+15
# rmse           1.185707e+01
# Name: 25, dtype: float64
#
# Seluruh hasil kombinasi hyperparameter rolling window median:
# window_size: 3, Tolerance: 0.5 -> RMSE: 19.780
# window_size: 3, Tolerance: 1 -> RMSE: 22.497
# window_size: 3, Tolerance: 2 -> RMSE: 37.821
# window_size: 3, Tolerance: 2.5 -> RMSE: 37.821
# window_size: 3, Tolerance: 3 -> RMSE: 37.821
# window_size: 3, Tolerance: 0.5 -> RMSE: 19.780
# window_size: 3, Tolerance: 1 -> RMSE: 22.497
# window_size: 3, Tolerance: 2 -> RMSE: 37.821
# window_size: 3, Tolerance: 2.5 -> RMSE: 37.821
# window_size: 3, Tolerance: 3 -> RMSE: 37.821
# window_size: 3, Tolerance: 0.5 -> RMSE: 19.780
# window_size: 3, Tolerance: 1 -> RMSE: 22.497
# window_size: 3, Tolerance: 2 -> RMSE: 37.821
# window_size: 3, Tolerance: 2.5 -> RMSE: 37.821
# window_size: 3, Tolerance: 3 -> RMSE: 37.821
# window_size: 3, Tolerance: 0.5 -> RMSE: 19.780
# window_size: 3, Tolerance: 1 -> RMSE: 22.497
# window_size: 3, Tolerance: 2 -> RMSE: 37.821
# window_size: 3, Tolerance: 2.5 -> RMSE: 37.821
# window_size: 3, Tolerance: 3 -> RMSE: 37.821
# window_size: 3, Tolerance: 0.5 -> RMSE: 19.780
# window_size: 3, Tolerance: 1 -> RMSE: 22.497
# window_size: 3, Tolerance: 2 -> RMSE: 37.821
# window_size: 3, Tolerance: 2.5 -> RMSE: 37.821
# window_size: 3, Tolerance: 3 -> RMSE: 37.821
# window_size: 8, Tolerance: 0.5 -> RMSE: 11.857
# window_size: 8, Tolerance: 1 -> RMSE: 21.460
# window_size: 8, Tolerance: 2 -> RMSE: 31.808
# window_size: 8, Tolerance: 2.5 -> RMSE: 37.796
# window_size: 8, Tolerance: 3 -> RMSE: 37.821
# window_size: 8, Tolerance: 0.5 -> RMSE: 11.857
# window_size: 8, Tolerance: 1 -> RMSE: 21.460
# window_size: 8, Tolerance: 2 -> RMSE: 31.808
# window_size: 8, Tolerance: 2.5 -> RMSE: 37.796
# window_size: 8, Tolerance: 3 -> RMSE: 37.821
# window_size: 8, Tolerance: 0.5 -> RMSE: 11.857
# window_size: 8, Tolerance: 1 -> RMSE: 21.460
# window_size: 8, Tolerance: 2 -> RMSE: 31.808
# window_size: 8, Tolerance: 2.5 -> RMSE: 37.796
# window_size: 8, Tolerance: 3 -> RMSE: 37.821
# window_size: 8, Tolerance: 0.5 -> RMSE: 11.857
# window_size: 8, Tolerance: 1 -> RMSE: 21.460
# window_size: 8, Tolerance: 2 -> RMSE: 31.808
# window_size: 8, Tolerance: 2.5 -> RMSE: 37.796
# window_size: 8, Tolerance: 3 -> RMSE: 37.821
# window_size: 8, Tolerance: 0.5 -> RMSE: 11.857
# window_size: 8, Tolerance: 1 -> RMSE: 21.460
# window_size: 8, Tolerance: 2 -> RMSE: 31.808
# window_size: 8, Tolerance: 2.5 -> RMSE: 37.796
# window_size: 8, Tolerance: 3 -> RMSE: 37.821
# window_size: 9, Tolerance: 0.5 -> RMSE: 13.249
# window_size: 9, Tolerance: 1 -> RMSE: 23.235
# window_size: 9, Tolerance: 2 -> RMSE: 25.811
# window_size: 9, Tolerance: 2.5 -> RMSE: 37.751
# window_size: 9, Tolerance: 3 -> RMSE: 37.821
# window_size: 9, Tolerance: 0.5 -> RMSE: 13.249
# window_size: 9, Tolerance: 1 -> RMSE: 23.235
# window_size: 9, Tolerance: 2 -> RMSE: 25.811
# window_size: 9, Tolerance: 2.5 -> RMSE: 37.751
# window_size: 9, Tolerance: 3 -> RMSE: 37.821
# window_size: 9, Tolerance: 0.5 -> RMSE: 13.249
# window_size: 9, Tolerance: 1 -> RMSE: 23.235
# window_size: 9, Tolerance: 2 -> RMSE: 25.811
# window_size: 9, Tolerance: 2.5 -> RMSE: 37.751
# window_size: 9, Tolerance: 3 -> RMSE: 37.821
# window_size: 9, Tolerance: 0.5 -> RMSE: 13.249
# window_size: 9, Tolerance: 1 -> RMSE: 23.235
# window_size: 9, Tolerance: 2 -> RMSE: 25.811
# window_size: 9, Tolerance: 2.5 -> RMSE: 37.751
# window_size: 9, Tolerance: 3 -> RMSE: 37.821
# window_size: 9, Tolerance: 0.5 -> RMSE: 13.249
# window_size: 9, Tolerance: 1 -> RMSE: 23.235
# window_size: 9, Tolerance: 2 -> RMSE: 25.811
# window_size: 9, Tolerance: 2.5 -> RMSE: 37.751
# window_size: 9, Tolerance: 3 -> RMSE: 37.821

# %% [markdown]
# Outlier handling Rolling Window Median

# %%
# Ambil kombinasi hyperparameter terbaik
best_window_size = 8
best_tolerance = 0.5

# Salin data asli
buku_400_copy = buku_400.copy()

# Rolling median dan rolling std
buku_400_copy['rolling_median'] = buku_400_copy['Jumlah_buku_dipinjam'].rolling(window=best_window_size, center=True).median()
buku_400_copy['rolling_std'] = buku_400_copy['Jumlah_buku_dipinjam'].rolling(window=best_window_size, center=True).std()

# Batas atas dan bawah
upper_bound = buku_400_copy['rolling_median'] + best_tolerance * buku_400_copy['rolling_std']
lower_bound = buku_400_copy['rolling_median'] - best_tolerance * buku_400_copy['rolling_std']

# Deteksi outlier awal
detected_outliers = (buku_400_copy['Jumlah_buku_dipinjam'] > upper_bound) | \
                    (buku_400_copy['Jumlah_buku_dipinjam'] < lower_bound)

# Ganti outlier dengan rolling median
buku_400_copy.loc[detected_outliers, 'Jumlah_buku_dipinjam'] = buku_400_copy.loc[detected_outliers, 'rolling_median']

# Buat DataFrame untuk visualisasi
buku_400_copy['Status'] = 'Setelah Outlier Handling'
buku_400['Status'] = 'Sebelum Outlier Handling'

df_visual = pd.concat([buku_400[['Jumlah_buku_dipinjam', 'Status']], 
                    buku_400_copy[['Jumlah_buku_dipinjam', 'Status']]])

# Plot Boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(x='Status', y='Jumlah_buku_dipinjam', data=df_visual)
plt.show()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_21728\766347803.py:21: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 42.   48.5  54.5  70.   85.   90.   70.   54.5  45.5  61.   66.   66.
#   52.5 108.5 122.  123.  126.  134.  137.5   0.    9.5   5.   19.5  25.
#   20.5  20.5  26.5  24.5  25.   27.   31.   36.5  31.   30.5  30.   24.
#   15.5  15.5  17.5  16.   19.   18.   15.   11.5  13.   16.5  16.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   buku_400_copy.loc[detected_outliers, 'Jumlah_buku_dipinjam'] = buku_400_copy.loc[detected_outliers, 'rolling_median']

# %%
plt.figure(figsize=(12, 6))
plt.plot(buku_400['Bulan'], buku_400['Jumlah_buku_dipinjam'], label='Sebelum Outlier Handling')
plt.plot(buku_400_copy['Bulan'], buku_400_copy['Jumlah_buku_dipinjam'], label='Setelah Outlier Handling', color='orange')
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.show()

# %%
# Ambil data asli sebelum normalisasi untuk referensi
data_original = buku_400_copy[['Jumlah_buku_dipinjam']].values
bulan = buku_400_copy['Bulan'].values  # Ambil label bulan

# Ukuran figure
plt.figure(figsize=(14, 6))

# Daftar rasio split yang ingin ditampilkan
split_ratios = [0.6, 0.7, 0.8]
colors = ['green', 'orange', 'blue']
labels = ['70:30', '80:20', '90:10']

# Plot data original untuk semua bulan sebagai latar
plt.plot(bulan, data_original, label='Data Asli', color='black', alpha=0.5)

# Loop untuk setiap rasio split
for ratio, color, label in zip(split_ratios, colors, labels):
    split_idx = int(len(data_original) * ratio)
    data_train = data_original[:split_idx]
    data_test = data_original[split_idx:]

    bulan_train = bulan[:split_idx]
    bulan_test = bulan[split_idx:]

    # Plot garis split
    plt.axvline(x=bulan[split_idx], color=color, linestyle='--', label=f'Split {label}')

# Label dan tampilan
plt.xticks(rotation=45)
plt.xlabel('Bulan')
plt.ylabel('Jumlah Buku Dipinjam')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Data split 60:40

# %% [markdown]
# Hyperparameter Tunning

# %%
# Data awal
X_raw = buku_400_copy[['Jumlah_buku_dipinjam']].values

# Fungsi membuat data dengan timestep
def create_timestep_data(data, timestep):
    X, y = [], []
    for i in range(len(data) - timestep):
        X.append(data[i:i+timestep])
        y.append(data[i+timestep])
    return np.array(X), np.array(y)

# Grid Search Parameter
param_grid = {
    'timestep': [12, 24],
    'epochs': [50, 100, 170],
    'batch_size': [32, 64, 128],
    'gru_units': [10, 20, 100],
    'cnn_filters': [16, 32, 128],
}

# Inisialisasi variabel terbaik
best_rmse = float('inf')
best_params = None
results = []

# Iterasi seluruh kombinasi parameter
for params in ParameterGrid(param_grid):
    timestep = params['timestep']
    print(f"\nTesting combination: {params}")

    # Buat ulang data dengan timestep baru
    X, y = create_timestep_data(X_raw, timestep)

    # Split train-test (tanpa shuffle)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, shuffle=False)

    # Reshape data agar sesuai dengan input model CNN-GRU
    X_train = X_train.reshape((X_train.shape[0], timestep, 1))
    X_test = X_test.reshape((X_test.shape[0], timestep, 1))

    # Normalisasi target
    scaler = MinMaxScaler()
    y_train_scaled = scaler.fit_transform(y_train.reshape(-1, 1))
    y_test_scaled = scaler.transform(y_test.reshape(-1, 1))

    # Bangun model CNN-GRU
    model = Sequential()

    # CNN Layer
    model.add(Conv1D(filters=params['cnn_filters'], kernel_size=1, activation='relu', input_shape=(timestep, 1)))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Flatten())  

    # Reshape sebelum masuk ke GRU
    model.add(Reshape((1, -1)))

    # GRU Layer
    model.add(GRU(params['gru_units'], activation='relu'))  
    model.add(Dropout(0.2))  

    # Output Layer
    model.add(Dense(1))

    # Compile model
    model.compile(optimizer='adam', loss='mean_squared_error')

    # Train model
    model.fit(X_train, y_train_scaled, epochs=params['epochs'], batch_size=params['batch_size'], verbose=0)
    
    # Evaluate model
    y_pred = model.predict(X_test)
    y_pred_inverse = scaler.inverse_transform(y_pred)
    y_test_inverse = scaler.inverse_transform(y_test_scaled)
    
    mse = mean_squared_error(y_test_inverse, y_pred_inverse)
    rmse = np.sqrt(mse)

    print(f"RMSE: {rmse}")

    # Simpan hasil tuning
    results.append((params, rmse))
    
    # Simpan kombinasi terbaik
    if rmse < best_rmse:
        best_rmse = rmse
        best_params = params

# Print hasil terbaik
print(f"\nBest RMSE: {best_rmse}")
print(f"Best parameters: {best_params}")

# Display seluruh hasil tuning
for res in results:
    print(f"Params: {res[0]} -> RMSE: {res[1]}")

# Simpan hasil tuning ke Excel
results_df = pd.DataFrame([
    {
        'timestep': r[0]['timestep'],
        'epochs': r[0]['epochs'],
        'batch_size': r[0]['batch_size'],
        'gru_units': r[0]['gru_units'],
        'cnn_filters': r[0]['cnn_filters'],
        'RMSE': r[1]
    }
    for r in results
])

# Simpan ke file Excel
results_df.to_excel("tuning buku_400 60,40.xlsx", index=False)
# Out:
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# RMSE: 54.10805277660307
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# RMSE: 141.9267537055708
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/stepWARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001F81D610310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# RMSE: 26.47950383709134
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001F81D8E8EE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# RMSE: 185.6922947591051
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# RMSE: 11.118632238062169
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# RMSE: 43.667922530400105
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# RMSE: 12.918082375708606
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# RMSE: 11.846563877804778
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# RMSE: 30.131476609810434
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 25.76041382246742
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# RMSE: 15.241950075908271
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 17.501064101251472
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# RMSE: 22.367593611475883
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 24.819443417919274
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# RMSE: 12.55146305353232
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# RMSE: 15.843451056570709
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# RMSE: 16.792333573783573
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# RMSE: 32.66442103816706
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# RMSE: 29.31249099252223
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# RMSE: 13.505280318392732
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# RMSE: 35.97216637061061
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 13.715912766518828
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# RMSE: 12.274207551654444
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 18.202323442112768
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# RMSE: 24.178349667482
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# RMSE: 7.93457140359792
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step
# RMSE: 9.501032749004102
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 10.48394949472558
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# RMSE: 11.094926490965635
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 19.015090987334926
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# RMSE: 10.759121406796211
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# RMSE: 12.81479032333797
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# RMSE: 11.154054016704766
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 28.95425103661797
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# RMSE: 13.262862876243883
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# RMSE: 20.06495872872247
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# RMSE: 21.662238678007654
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# RMSE: 10.621263324230037
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# RMSE: 7.792602075087368
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# RMSE: 16.306614864486477
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# RMSE: 9.802196614039188
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# RMSE: 17.931973400026628
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# RMSE: 7.124310106005397
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# RMSE: 7.894791415999539
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# RMSE: 5.325866278438705
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 8.005019131238866
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# RMSE: 10.452473460523542
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 11.891319879776477
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# RMSE: 14.427458086160888
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# RMSE: 8.507212782123693
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# RMSE: 7.668502443839794
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# RMSE: 11.207120230153704
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# RMSE: 7.572439815129448
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 12.203716855601225
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# RMSE: 114.42012889988743
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# RMSE: 98.50337939833683
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# RMSE: 91.78402028209533
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 71.60585917920936
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# RMSE: 22.72444423770615
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# RMSE: 88.12039916651852
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# RMSE: 30.723430938601727
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 37.34981960640082
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# RMSE: 40.29044978507692
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 67.49257496507857
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# RMSE: 12.127220015512851
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# RMSE: 23.363591019664778
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# RMSE: 94.42720691300185
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 61.449472573613875
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# RMSE: 16.12355331379854
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# RMSE: 53.374460278300624
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# RMSE: 18.13227900964434
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# RMSE: 49.683470032130074
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# RMSE: 16.46045197763948
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 21.899280905994047
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# RMSE: 37.558649332934195
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 21.30906770744752
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# RMSE: 22.66084772275294
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 52.53499910518878
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# RMSE: 23.674803477394892
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# RMSE: 9.713171479007888
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# RMSE: 12.64872859120589
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# RMSE: 28.13435313841891
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# RMSE: 29.272658410795493
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 21.038208225102387
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# ...
# Params: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 11.154054016704766
# Params: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 28.95425103661797
# Params: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 13.262862876243883
# Params: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 20.06495872872247
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 21.662238678007654
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 10.621263324230037
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 7.792602075087368
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 16.306614864486477
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 9.802196614039188
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 17.931973400026628
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 7.124310106005397
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 7.894791415999539
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 5.325866278438705
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 8.005019131238866
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 10.452473460523542
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 11.891319879776477
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 14.427458086160888
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 8.507212782123693
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 7.668502443839794
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 11.207120230153704
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 7.572439815129448
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 12.203716855601225
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 114.42012889988743
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 98.50337939833683
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 91.78402028209533
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 71.60585917920936
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 22.72444423770615
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 88.12039916651852
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 30.723430938601727
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 37.34981960640082
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 40.29044978507692
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 67.49257496507857
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 12.127220015512851
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 23.363591019664778
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 94.42720691300185
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 61.449472573613875
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 16.12355331379854
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 53.374460278300624
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 18.13227900964434
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 49.683470032130074
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 16.46045197763948
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 21.899280905994047
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 37.558649332934195
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 21.30906770744752
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 22.66084772275294
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 52.53499910518878
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 23.674803477394892
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 9.713171479007888
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 12.64872859120589
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 28.13435313841891
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 29.272658410795493
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 21.038208225102387
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 14.05150858812012
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 16.28609496658526
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 21.77358602557534
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 36.248514953494066
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 20.332648728199718
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 17.971897527666396
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 14.00350584826024
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 20.866018393311148
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 10.915876465427463
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 21.430572890645287
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 14.052423591820432
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 21.80585507891486
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 6.341276610872245
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 19.708758111984547
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 19.894563870716983
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 18.003218276342523
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 11.569746533311685
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 13.276778310343593
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 9.804583878686143
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 8.437053387496997
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 6.338102012183347
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 14.662953992701695
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 11.473618182889945
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 13.223076561432654
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 13.99351917688736
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 6.8537006195984285
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 80.75161399156548
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 46.19900959860841
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 36.369301091723486
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 40.56130376355296
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 16.04654391639802
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 12.166592577998607
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 27.081202518349674
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 13.884214224782681
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 21.717616705670128
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 58.14177886565535
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 25.178223128294277
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 19.351553310765997
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 40.16566507229298
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 8.263638841649971
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 12.627965541508301
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 44.08393213424778
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 18.841168625726844
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 23.391804365386513
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 39.78174637156661
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 52.03346802702622
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 25.23996464543021
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 36.776028275622
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 9.347546047063341
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 21.715432165765616
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 10.318169334011818
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 19.756896064574967
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 25.540338289466693
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 28.52673927987263
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 12.834030046117157
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 8.57475288773801
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 8.22314575302117
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 6.930800814253942
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 20.111306775123694
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 22.25857334902249
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 7.575253997936201
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 20.508364822533395
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 7.103787138427079
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 7.548190127156005
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 10.70643954153814
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 14.143989936967653
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 14.200404300857818
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 19.034119210480622
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 7.463331361227879
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 19.726860078176653
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 12.551496730094156
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 18.135545854154582
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 7.4094185629017835
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 15.200139632761525
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 6.648781392037009
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 13.270492768057105
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 10.5228235830183
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 10.208308617206535

# %% [markdown]
# Model CNN-GRU

# %%
# Parameter window size
timestep = 12  # Menggunakan 6 bulan terakhir sebagai input

# Membentuk data input dengan sliding window
def create_sliding_window(data, timestep):
    X, y = [], []
    for i in range(len(data) - timestep):
        X.append(data[i:i+timestep])
        y.append(data[i+timestep])
    return np.array(X), np.array(y)

# Memisahkan fitur dan target
X = buku_400_copy[['Jumlah_buku_dipinjam']].values
y = buku_400_copy[['Jumlah_buku_dipinjam']].values

# Normalisasi data
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Membuat dataset sliding window
X_window, y_window = create_sliding_window(X_scaled, timestep)

# Split data menjadi train dan test (80% training, 20% testing)
split_idx = int(len(X_window) * 0.6)
X_train, X_test = X_window[:split_idx], X_window[split_idx:]
y_train, y_test = y_window[:split_idx], y_window[split_idx:]

# Reshape input menjadi tiga dimensi (samples, timesteps, features)
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Membangun Model CNN-GRU
model_cnn_gru = Sequential()

# Lapisan CNN
model_cnn_gru.add(Conv1D(filters=128, kernel_size=1, activation='relu', input_shape=(timestep, 1)))
model_cnn_gru.add(MaxPooling1D(pool_size=2))
model_cnn_gru.add(Flatten())

# Ubah kembali ke bentuk tiga dimensi untuk input ke GRU
model_cnn_gru.add(Reshape((1, -1)))

# Lapisan GRU setelah CNN
model_cnn_gru.add(GRU(20, activation='relu'))
model_cnn_gru.add(Dropout(0.2))

# Lapisan output
model_cnn_gru.add(Dense(1))

# Kompilasi model
model_cnn_gru.compile(optimizer='adam', loss='mean_squared_error')

# Latih model
history_model = model_cnn_gru.fit(X_train, y_train, epochs=100, batch_size=32)

# Prediksi pada data uji
y_pred_cnn_gru = model_cnn_gru.predict(X_test)

# Konversi kembali ke skala asli
y_pred_cnn_gru_inverse = scaler.inverse_transform(y_pred_cnn_gru)
y_test_inverse = scaler.inverse_transform(y_test)

# Evaluasi model
mse = mean_squared_error(y_test_inverse, y_pred_cnn_gru_inverse)
rmse = np.sqrt(mse)
mape = mean_absolute_percentage_error(y_test_inverse, y_pred_cnn_gru_inverse) * 100
mae = mean_absolute_error(y_test_inverse, y_pred_cnn_gru_inverse)

print(f"RMSE: {rmse}")
print(f"MAPE: {mape:.2f}%")

# Plot hasil model (data aktual vs prediksi)
plt.figure(figsize=(14, 6))
plt.plot(buku_400_copy['Bulan'][-len(y_test_inverse):], y_test_inverse, label='Actual', color='blue')
plt.plot(buku_400_copy['Bulan'][-len(y_pred_cnn_gru_inverse):], y_pred_cnn_gru_inverse, label='Predicted', linestyle='--', color='red')
plt.title('Perbandingan Hasil Model CNN-GRU pada Data Uji')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Buku Dipinjam')
plt.legend()
plt.show()

# plot loss
plt.figure(figsize=(14, 6))
plt.plot(history_model.history['loss'], label='Train Loss')
plt.title('Loss History')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.2673
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1975
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1271
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0850
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0853
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1006
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1065
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1020
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0756
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0648
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0714
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0607
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0468
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0473
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0654
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0544
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0395
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0487
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0423
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0498
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0487
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0586
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0426
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0440
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0375
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0373
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0313
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0262
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0405
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0337
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0295
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0347
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0419
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0331
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0310
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0259
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0292
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0255
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0279
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0221
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0274
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0231
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0294
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0204
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0364
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0191
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0183
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0161
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0251
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0305
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0227
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0204
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0236
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0232
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0192
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0297
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0188
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0200
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0244
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0213
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0187
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0229
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0206
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0264
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0166
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0209
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0228
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0166
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0180
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0234
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0216
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0178
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0186
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0208
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0196
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0175
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0179
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0163
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0167
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0219
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0214
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0195
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0156
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0159
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0187
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0168
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0212
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0156
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0143
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0221
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0251
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0133
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0147
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0206
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0150
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0207
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0179
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0162
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0204
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# RMSE: 5.549077683853327
# MAPE: 22.27%

# %%
# Prediksi 12 bulan ke depan menggunakan sliding window
def predict_future(model, last_input, months=12):
    future_predictions = []
    current_input = last_input.copy()

    for _ in range(months):
        prediction = model.predict(current_input.reshape((1, timestep, 1)))
        future_predictions.append(prediction[0, 0])
        
        # Geser input window dengan menambahkan prediksi terbaru
        current_input = np.roll(current_input, -1)
        current_input[-1] = prediction[0, 0]

    return np.array(future_predictions).reshape(-1, 1)

# Gunakan data terakhir sebagai input awal
last_input = X_scaled[-timestep:]
future_preds_scaled = predict_future(model_cnn_gru, last_input, months=12)

# Cek nilai sebelum inverse transform
print("Prediksi dalam skala normalisasi:")
print(future_preds_scaled)

# Konversi kembali ke skala asli
future_preds = scaler.inverse_transform(future_preds_scaled)

# Konversi kembali ke skala asli dan ubah ke bilangan bulat
future_preds = scaler.inverse_transform(future_preds_scaled).astype(int)

# Cek nilai setelah inverse transform
print("Prediksi dalam skala asli:")
print(future_preds)

# Buat label bulan untuk prediksi
future_dates = pd.date_range(start=buku_400_copy['Bulan'].values[-1], periods=12, freq='M')

# Simpan hasil prediksi dalam DataFrame untuk analisis lebih lanjut
predictions_df = pd.DataFrame({'Bulan': future_dates, 'Prediksi': future_preds.flatten()})
print("Hasil prediksi dalam DataFrame:")
print(predictions_df)

# Gabungkan data aktual dan prediksi
combined_dates = np.concatenate([buku_400_copy['Bulan'].values, future_dates])
combined_values = np.concatenate([buku_400_copy['Jumlah_buku_dipinjam'].values, future_preds.flatten()])

# Visualisasi hasil prediksi dengan satu garis tetapi warna berbeda
plt.figure(figsize=(14, 8))

# Plot data aktual dengan warna biru
plt.plot(combined_dates[:len(buku_400_copy)], combined_values[:len(buku_400_copy)], color='blue', label='Actual Data')

# Plot data prediksi dengan warna merah (melanjutkan garis sebelumnya)
plt.plot(combined_dates[len(buku_400_copy)-1:], combined_values[len(buku_400_copy)-1:], color='red', label='CNN-GRU Forecast')
plt.xticks(fontsize=29)
plt.yticks(fontsize=35)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Prediksi dalam skala normalisasi:
# [[0.16809471]
#  [0.16667521]
#  [0.16718523]
#  [0.16539374]
#  [0.16090639]
#  [0.15336558]
#  [0.15018468]
#  [0.14493312]
#  [0.13787532]
#  [0.1280233 ]
#  [0.12240532]
#  [0.11558503]]
# Prediksi dalam skala asli:
# [[25]
#  [25]
#  [25]
#  [24]
#  [24]
#  [23]
#  [22]
#  [21]
#  [20]
#  [19]
#  [18]
#  [17]]
# Hasil prediksi dalam DataFrame:
#         Bulan  Prediksi
# 0  2024-12-31        25
# 1  2025-01-31        25
# 2  2025-02-28        25
# 3  2025-03-31        24
# 4  2025-04-30        24
# 5  2025-05-31        23
# 6  2025-06-30        22
# 7  2025-07-31        21
# 8  2025-08-31        20
# 9  2025-09-30        19
# 10 2025-10-31        18
# 11 2025-11-30        17
# C:\Users\asus\AppData\Local\Temp\ipykernel_21728\3294997592.py:35: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=buku_400_copy['Bulan'].values[-1], periods=12, freq='M')

# %% [markdown]
# # Data split 70:30

# %% [markdown]
# Hyperparameter Tunning

# %%
# Data awal
X_raw = buku_400_copy[['Jumlah_buku_dipinjam']].values

# Fungsi membuat data dengan timestep
def create_timestep_data(data, timestep):
    X, y = [], []
    for i in range(len(data) - timestep):
        X.append(data[i:i+timestep])
        y.append(data[i+timestep])
    return np.array(X), np.array(y)

# Grid Search Parameter
param_grid = {
    'timestep': [12, 24],
    'epochs': [50, 100, 170],
    'batch_size': [32, 64, 128],
    'gru_units': [10, 20, 100],
    'cnn_filters': [16, 32, 128],
}

# Inisialisasi variabel terbaik
best_rmse = float('inf')
best_params = None
results = []

# Iterasi seluruh kombinasi parameter
for params in ParameterGrid(param_grid):
    timestep = params['timestep']
    print(f"\nTesting combination: {params}")

    # Buat ulang data dengan timestep baru
    X, y = create_timestep_data(X_raw, timestep)

    # Split train-test (tanpa shuffle)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=False)

    # Reshape data agar sesuai dengan input model CNN-GRU
    X_train = X_train.reshape((X_train.shape[0], timestep, 1))
    X_test = X_test.reshape((X_test.shape[0], timestep, 1))

    # Normalisasi target
    scaler = MinMaxScaler()
    y_train_scaled = scaler.fit_transform(y_train.reshape(-1, 1))
    y_test_scaled = scaler.transform(y_test.reshape(-1, 1))

    # Bangun model CNN-GRU
    model = Sequential()

    # CNN Layer
    model.add(Conv1D(filters=params['cnn_filters'], kernel_size=1, activation='relu', input_shape=(timestep, 1)))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Flatten())  

    # Reshape sebelum masuk ke GRU
    model.add(Reshape((1, -1)))

    # GRU Layer
    model.add(GRU(params['gru_units'], activation='relu'))  
    model.add(Dropout(0.2))  

    # Output Layer
    model.add(Dense(1))

    # Compile model
    model.compile(optimizer='adam', loss='mean_squared_error')

    # Train model
    model.fit(X_train, y_train_scaled, epochs=params['epochs'], batch_size=params['batch_size'], verbose=0)
    
    # Evaluate model
    y_pred = model.predict(X_test)
    y_pred_inverse = scaler.inverse_transform(y_pred)
    y_test_inverse = scaler.inverse_transform(y_test_scaled)
    
    mse = mean_squared_error(y_test_inverse, y_pred_inverse)
    rmse = np.sqrt(mse)

    print(f"RMSE: {rmse}")

    # Simpan hasil tuning
    results.append((params, rmse))
    
    # Simpan kombinasi terbaik
    if rmse < best_rmse:
        best_rmse = rmse
        best_params = params

# Print hasil terbaik
print(f"\nBest RMSE: {best_rmse}")
print(f"Best parameters: {best_params}")

# Display seluruh hasil tuning
for res in results:
    print(f"Params: {res[0]} -> RMSE: {res[1]}")

# Simpan hasil tuning ke Excel
results_df = pd.DataFrame([
    {
        'timestep': r[0]['timestep'],
        'epochs': r[0]['epochs'],
        'batch_size': r[0]['batch_size'],
        'gru_units': r[0]['gru_units'],
        'cnn_filters': r[0]['cnn_filters'],
        'RMSE': r[1]
    }
    for r in results
])

# Simpan ke file Excel
results_df.to_excel("tuning buku_400 70,30.xlsx", index=False)
# Out:
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# RMSE: 58.92596032569328
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# RMSE: 15.477360174570004
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 37.573924905175076
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 14.536790003069278
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# RMSE: 34.12034387884571
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# RMSE: 41.518745781194696
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# RMSE: 31.824619574673054
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# RMSE: 12.206168060535612
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 13.664354280787858
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# RMSE: 12.600154940665393
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# RMSE: 9.766092136005675
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 29.60278200696738
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 11.971502833936361
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# RMSE: 5.840146641583392
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 12.699205286815836
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 8.388180281300539
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# RMSE: 12.158346883431223
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# RMSE: 25.149803430655847
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 17.33724094463143
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# RMSE: 15.69938668777222
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# RMSE: 7.654169122247074
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 7.250040103398528
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 30.266825201650676
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 20.458542631673797
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# RMSE: 28.823991621293096
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# RMSE: 9.263933768291732
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# RMSE: 5.857656707145107
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 12.355231091548443
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 11.857696284638138
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# RMSE: 20.0712143408999
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 15.350591990415376
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# RMSE: 13.34473175265308
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 6.497310147801923
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 5.640092723063863
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 15.055933063428125
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# RMSE: 17.07565568118353
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# RMSE: 6.4935212166447585
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# RMSE: 5.667271680186782
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# RMSE: 7.116106112805543
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 12.368730598661703
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 12.546810397821245
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 10.480733667933332
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 9.002388284298677
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 6.691183992219099
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 7.932756464425693
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 4.096321396957166
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 10.122903903139497
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 9.966894129104793
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 10.94535283447295
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# RMSE: 13.872464299083422
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 7.958219951122215
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 12.783509570876996
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 7.092050091619811
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# RMSE: 11.972761330467689
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# RMSE: 10.85553785349906
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 29.24932285017662
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# RMSE: 26.08153264208573
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# RMSE: 23.746259199018844
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 30.87529909384599
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# RMSE: 26.83372030546057
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 15.173532124097578
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# RMSE: 34.105242091138386
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 22.62009978607415
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# RMSE: 37.104642675224696
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 14.548743263435913
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# RMSE: 12.788548562372172
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# RMSE: 6.432618337860977
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 12.981007908686406
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 12.861037751029015
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# RMSE: 4.801287405347722
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 22.48439196333905
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# RMSE: 11.916344212725754
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 22.344049135797494
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 17.758562004503876
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# RMSE: 8.482929411271412
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 15.058683598521176
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# RMSE: 49.433746683241665
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 24.3407342560763
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 32.75197430823097
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 14.143828223116142
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# RMSE: 13.907142797430588
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# RMSE: 10.444256457260769
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# RMSE: 9.952955862387984
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# RMSE: 14.557970237264382
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 4.617666781895168
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 3.9985336705702355
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 6.482166969444634
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 24}
# ...
# Params: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 6.497310147801923
# Params: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 5.640092723063863
# Params: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 15.055933063428125
# Params: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 17.07565568118353
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 6.4935212166447585
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 5.667271680186782
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 7.116106112805543
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 12.368730598661703
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 12.546810397821245
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 10.480733667933332
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 9.002388284298677
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 6.691183992219099
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 7.932756464425693
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 4.096321396957166
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 10.122903903139497
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 9.966894129104793
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 10.94535283447295
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 13.872464299083422
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 7.958219951122215
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 12.783509570876996
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 7.092050091619811
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 11.972761330467689
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 10.85553785349906
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 29.24932285017662
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 26.08153264208573
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 23.746259199018844
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 30.87529909384599
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 26.83372030546057
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 15.173532124097578
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 34.105242091138386
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 22.62009978607415
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 37.104642675224696
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 14.548743263435913
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 12.788548562372172
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 6.432618337860977
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 12.981007908686406
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 12.861037751029015
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 4.801287405347722
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 22.48439196333905
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 11.916344212725754
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 22.344049135797494
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 17.758562004503876
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 8.482929411271412
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 15.058683598521176
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 49.433746683241665
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 24.3407342560763
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 32.75197430823097
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 14.143828223116142
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 13.907142797430588
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 10.444256457260769
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 9.952955862387984
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 14.557970237264382
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 4.617666781895168
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 3.9985336705702355
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 6.482166969444634
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 10.306005466807736
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 15.553693711610512
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 14.167094233557043
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 8.241239966689974
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 14.759607116986162
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 16.314811148500723
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 15.848614537097031
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 12.929811247237813
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 16.83438889909336
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 4.89497005419052
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 11.291867280554975
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 16.712918759727195
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 13.562752253164861
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 5.988110150217767
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 10.150090653165257
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 11.915226359303148
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 9.377373271129478
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 9.594283544783629
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 8.226898241248064
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 7.391245618463849
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 15.48499115427096
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 126.21234497265424
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 109.65123981096905
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 20.519944819835665
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 21.225680342731614
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 23.781962515476877
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 111.74827302004928
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 16.897928013627727
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 13.753305605598998
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 49.75027558819462
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 19.424847743669847
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 19.455141214670768
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 16.78491035682846
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 10.24439264357659
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 15.830176860104036
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 25.60042874386524
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 19.312049597534465
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 12.15969289311412
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 13.779076107831312
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 35.26730679875471
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 15.362365527534648
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 9.166982739815992
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 55.407225153865014
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 10.856850467469608
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 25.55134748638405
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 19.54606501564607
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 15.982113205060093
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 16.903462469103594
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 14.856370381264549
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 9.262703628643196
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 15.993965100406962
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 11.142167834352358
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 12.473669574253869
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 17.306334465644966
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 12.248663032217186
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 13.211616111667174
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 13.363000269024816
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 8.337335314635384
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 15.425067058698414
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 5.906740381801081
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 15.690090981342586
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 8.4935135108829
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 13.753729586459851
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 10.297254729754012
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 10.746926664001819
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 13.204205722891055
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 8.571661329190404
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 7.683130499783362
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 9.073329082638535
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 13.558934177357962
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 6.40446669741552
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 6.026768577931345
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 8.928292537988419
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 7.888802277076236
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 14.261148028072169

# %% [markdown]
# Model CNN-GRU

# %%
# Parameter window size
timestep = 24  # Menggunakan 6 bulan terakhir sebagai input

# Membentuk data input dengan sliding window
def create_sliding_window(data, timestep):
    X, y = [], []
    for i in range(len(data) - timestep):
        X.append(data[i:i+timestep])
        y.append(data[i+timestep])
    return np.array(X), np.array(y)

# Memisahkan fitur dan target
X = buku_400_copy[['Jumlah_buku_dipinjam']].values
y = buku_400_copy[['Jumlah_buku_dipinjam']].values

# Normalisasi data
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Membuat dataset sliding window
X_window, y_window = create_sliding_window(X_scaled, timestep)

# Split data menjadi train dan test (80% training, 20% testing)
split_idx = int(len(X_window) * 0.7)
X_train, X_test = X_window[:split_idx], X_window[split_idx:]
y_train, y_test = y_window[:split_idx], y_window[split_idx:]

# Reshape input menjadi tiga dimensi (samples, timesteps, features)
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Membangun Model CNN-GRU
model_cnn_gru = Sequential()

# Lapisan CNN
model_cnn_gru.add(Conv1D(filters=32, kernel_size=1, activation='relu', input_shape=(timestep, 1)))
model_cnn_gru.add(MaxPooling1D(pool_size=2))
model_cnn_gru.add(Flatten())

# Ubah kembali ke bentuk tiga dimensi untuk input ke GRU
model_cnn_gru.add(Reshape((1, -1)))

# Lapisan GRU setelah CNN
model_cnn_gru.add(GRU(10, activation='relu'))
model_cnn_gru.add(Dropout(0.2))

# Lapisan output
model_cnn_gru.add(Dense(1))

# Kompilasi model
model_cnn_gru.compile(optimizer='adam', loss='mean_squared_error')

# Latih model
history_model = model_cnn_gru.fit(X_train, y_train, epochs=170, batch_size=64)

# Prediksi pada data uji
y_pred_cnn_gru = model_cnn_gru.predict(X_test)

# Konversi kembali ke skala asli
y_pred_cnn_gru_inverse = scaler.inverse_transform(y_pred_cnn_gru)
y_test_inverse = scaler.inverse_transform(y_test)

# Evaluasi model
mse = mean_squared_error(y_test_inverse, y_pred_cnn_gru_inverse)
rmse = np.sqrt(mse)
mape = mean_absolute_percentage_error(y_test_inverse, y_pred_cnn_gru_inverse) * 100
mae = mean_absolute_error(y_test_inverse, y_pred_cnn_gru_inverse)

print(f"RMSE: {rmse}")
print(f"MAPE: {mape:.2f}%")

# Plot hasil model (data aktual vs prediksi)
plt.figure(figsize=(14, 6))
plt.plot(buku_400_copy['Bulan'][-len(y_test_inverse):], y_test_inverse, label='Actual', color='blue')
plt.plot(buku_400_copy['Bulan'][-len(y_pred_cnn_gru_inverse):], y_pred_cnn_gru_inverse, label='Predicted', linestyle='--', color='red')
plt.title('Perbandingan Hasil Model CNN-GRU pada Data Uji')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Buku Dipinjam')
plt.legend()
plt.show()

# plot loss
plt.figure(figsize=(14, 6))
plt.plot(history_model.history['loss'], label='Train Loss')
plt.title('Loss History')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/170
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.2827
# Epoch 2/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.2712
# Epoch 3/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.2644
# Epoch 4/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.2568
# Epoch 5/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.2465
# Epoch 6/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.2404
# Epoch 7/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.2271
# Epoch 8/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.2092
# Epoch 9/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.1963
# Epoch 10/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.1838
# Epoch 11/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.1748
# Epoch 12/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1680
# Epoch 13/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1573
# Epoch 14/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1570
# Epoch 15/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1359
# Epoch 16/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.1461
# Epoch 17/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.1454
# Epoch 18/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1392
# Epoch 19/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1127
# Epoch 20/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.1088
# Epoch 21/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1410
# Epoch 22/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1367
# Epoch 23/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.1261
# Epoch 24/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1393
# Epoch 25/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1616
# Epoch 26/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.1192
# Epoch 27/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0936
# Epoch 28/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.1141
# Epoch 29/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1157
# Epoch 30/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0950
# Epoch 31/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1135
# Epoch 32/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1117
# Epoch 33/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0899
# Epoch 34/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0964
# Epoch 35/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1014
# Epoch 36/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1268
# Epoch 37/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0852
# Epoch 38/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0852
# Epoch 39/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1394
# Epoch 40/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0897
# Epoch 41/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0926
# Epoch 42/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1053
# Epoch 43/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0735
# Epoch 44/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1045
# Epoch 45/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1378
# Epoch 46/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0684
# Epoch 47/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0778
# Epoch 48/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1014
# Epoch 49/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0768
# Epoch 50/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0952
# Epoch 51/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0793
# Epoch 52/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0866
# Epoch 53/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0676
# Epoch 54/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0733
# Epoch 55/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0917
# Epoch 56/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0656
# Epoch 57/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0695
# Epoch 58/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0814
# Epoch 59/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0637
# Epoch 60/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0679
# Epoch 61/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0824
# Epoch 62/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0922
# Epoch 63/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0481
# Epoch 64/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0664
# Epoch 65/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0620
# Epoch 66/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0772
# Epoch 67/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0587
# Epoch 68/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0714
# Epoch 69/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0643
# Epoch 70/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0739
# Epoch 71/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0732
# Epoch 72/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0624
# Epoch 73/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0514
# Epoch 74/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0517
# Epoch 75/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0701
# Epoch 76/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0772
# Epoch 77/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0652
# Epoch 78/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0492
# Epoch 79/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0515
# Epoch 80/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0897
# Epoch 81/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0648
# Epoch 82/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0578
# Epoch 83/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0455
# Epoch 84/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0411
# Epoch 85/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0668
# Epoch 86/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0621
# Epoch 87/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0476
# Epoch 88/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0648
# Epoch 89/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0490
# Epoch 90/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0590
# Epoch 91/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0442
# Epoch 92/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0653
# Epoch 93/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0520
# Epoch 94/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0643
# Epoch 95/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0617
# Epoch 96/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0749
# Epoch 97/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0597
# Epoch 98/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0474
# Epoch 99/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0469
# Epoch 100/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0433
# Epoch 101/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0310
# Epoch 102/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0770
# Epoch 103/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0392
# Epoch 104/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0451
# Epoch 105/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0697
# Epoch 106/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0473
# Epoch 107/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0635
# Epoch 108/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0543
# Epoch 109/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0468
# Epoch 110/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0619
# Epoch 111/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0380
# Epoch 112/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0484
# Epoch 113/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0541
# Epoch 114/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0352
# Epoch 115/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0346
# Epoch 116/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0387
# Epoch 117/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0494
# Epoch 118/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0423
# Epoch 119/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0261
# Epoch 120/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0683
# Epoch 121/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0392
# Epoch 122/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0515
# Epoch 123/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0389
# Epoch 124/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0466
# Epoch 125/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0561
# Epoch 126/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0620
# Epoch 127/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0353
# Epoch 128/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0413
# Epoch 129/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0574
# Epoch 130/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0273
# Epoch 131/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0265
# Epoch 132/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0262
# Epoch 133/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0376
# Epoch 134/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0499
# Epoch 135/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0396
# Epoch 136/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0613
# Epoch 137/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0322
# Epoch 138/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0642
# Epoch 139/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0483
# Epoch 140/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0271
# Epoch 141/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0360
# Epoch 142/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0260
# Epoch 143/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0529
# Epoch 144/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0434
# Epoch 145/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0544
# Epoch 146/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0453
# Epoch 147/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0459
# Epoch 148/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0411
# Epoch 149/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0522
# Epoch 150/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0363
# Epoch 151/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0564
# Epoch 152/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0538
# Epoch 153/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0475
# Epoch 154/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0462
# Epoch 155/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0609
# Epoch 156/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0519
# Epoch 157/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0213
# Epoch 158/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0228
# Epoch 159/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0541
# Epoch 160/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0334
# Epoch 161/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0263
# Epoch 162/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0327
# Epoch 163/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0457
# Epoch 164/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0424
# Epoch 165/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0362
# Epoch 166/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0460
# Epoch 167/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0374
# Epoch 168/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0449
# Epoch 169/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0285
# Epoch 170/170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0534
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# RMSE: 9.162097130030595
# MAPE: 48.31%

# %%
# Prediksi 12 bulan ke depan menggunakan sliding window
def predict_future(model, last_input, months=12):
    future_predictions = []
    current_input = last_input.copy()

    for _ in range(months):
        prediction = model.predict(current_input.reshape((1, timestep, 1)))
        future_predictions.append(prediction[0, 0])
        
        # Geser input window dengan menambahkan prediksi terbaru
        current_input = np.roll(current_input, -1)
        current_input[-1] = prediction[0, 0]

    return np.array(future_predictions).reshape(-1, 1)

# Gunakan data terakhir sebagai input awal
last_input = X_scaled[-timestep:]
future_preds_scaled = predict_future(model_cnn_gru, last_input, months=12)

# Cek nilai sebelum inverse transform
print("Prediksi dalam skala normalisasi:")
print(future_preds_scaled)

# Konversi kembali ke skala asli
future_preds = scaler.inverse_transform(future_preds_scaled)

# Konversi kembali ke skala asli dan ubah ke bilangan bulat
future_preds = scaler.inverse_transform(future_preds_scaled).astype(int)

# Cek nilai setelah inverse transform
print("Prediksi dalam skala asli:")
print(future_preds)

# Buat label bulan untuk prediksi
future_dates = pd.date_range(start=buku_400_copy['Bulan'].values[-1], periods=12, freq='M')

# Simpan hasil prediksi dalam DataFrame untuk analisis lebih lanjut
predictions_df = pd.DataFrame({'Bulan': future_dates, 'Prediksi': future_preds.flatten()})
print("Hasil prediksi dalam DataFrame:")
print(predictions_df)

# Gabungkan data aktual dan prediksi
combined_dates = np.concatenate([buku_400_copy['Bulan'].values, future_dates])
combined_values = np.concatenate([buku_400_copy['Jumlah_buku_dipinjam'].values, future_preds.flatten()])

# Visualisasi hasil prediksi dengan satu garis tetapi warna berbeda
plt.figure(figsize=(14, 8))

# Plot data aktual dengan warna biru
plt.plot(combined_dates[:len(buku_400_copy)], combined_values[:len(buku_400_copy)], color='blue', label='Actual Data')

# Plot data prediksi dengan warna merah (melanjutkan garis sebelumnya)
plt.plot(combined_dates[len(buku_400_copy)-1:], combined_values[len(buku_400_copy)-1:], color='red', label='CNN-GRU Forecast')

plt.title('Perbandingan Hasil Forecasting Peminjaman Buku')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Buku Dipinjam')
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Prediksi dalam skala normalisasi:
# [[0.19294453]
#  [0.20974709]
#  [0.22030097]
#  [0.23597589]
#  [0.25114542]
#  [0.2707207 ]
#  [0.2876745 ]
#  [0.3052163 ]
#  [0.3274905 ]
#  [0.34710234]
#  [0.364016  ]
#  [0.37684923]]
# Prediksi dalam skala asli:
# [[28]
#  [31]
#  [33]
#  [35]
#  [37]
#  [40]
#  [43]
#  [45]
#  [49]
#  [52]
#  [54]
#  [56]]
# Hasil prediksi dalam DataFrame:
#         Bulan  Prediksi
# 0  2024-12-31        28
# 1  2025-01-31        31
# 2  2025-02-28        33
# 3  2025-03-31        35
# 4  2025-04-30        37
# 5  2025-05-31        40
# 6  2025-06-30        43
# 7  2025-07-31        45
# 8  2025-08-31        49
# 9  2025-09-30        52
# 10 2025-10-31        54
# 11 2025-11-30        56
# C:\Users\asus\AppData\Local\Temp\ipykernel_22028\887585007.py:35: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=buku_400_copy['Bulan'].values[-1], periods=12, freq='M')

# %% [markdown]
# # Data split 80:20

# %% [markdown]
# Hyperparameter Tunning

# %%
# Data awal
X_raw = buku_400_copy[['Jumlah_buku_dipinjam']].values

# Fungsi membuat data dengan timestep
def create_timestep_data(data, timestep):
    X, y = [], []
    for i in range(len(data) - timestep):
        X.append(data[i:i+timestep])
        y.append(data[i+timestep])
    return np.array(X), np.array(y)

# Grid Search Parameter
param_grid = {
    'timestep': [12, 24],
    'epochs': [50, 100, 170],
    'batch_size': [32, 64, 128],
    'gru_units': [10, 20, 100],
    'cnn_filters': [16, 32, 128],
}

# Inisialisasi variabel terbaik
best_rmse = float('inf')
best_params = None
results = []

# Iterasi seluruh kombinasi parameter
for params in ParameterGrid(param_grid):
    timestep = params['timestep']
    print(f"\nTesting combination: {params}")

    # Buat ulang data dengan timestep baru
    X, y = create_timestep_data(X_raw, timestep)

    # Split train-test (tanpa shuffle)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

    # Reshape data agar sesuai dengan input model CNN-GRU
    X_train = X_train.reshape((X_train.shape[0], timestep, 1))
    X_test = X_test.reshape((X_test.shape[0], timestep, 1))

    # Normalisasi target
    scaler = MinMaxScaler()
    y_train_scaled = scaler.fit_transform(y_train.reshape(-1, 1))
    y_test_scaled = scaler.transform(y_test.reshape(-1, 1))

    # Bangun model CNN-GRU
    model = Sequential()

    # CNN Layer
    model.add(Conv1D(filters=params['cnn_filters'], kernel_size=1, activation='relu', input_shape=(timestep, 1)))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Flatten())  

    # Reshape sebelum masuk ke GRU
    model.add(Reshape((1, -1)))

    # GRU Layer
    model.add(GRU(params['gru_units'], activation='relu'))  
    model.add(Dropout(0.2))  

    # Output Layer
    model.add(Dense(1))

    # Compile model
    model.compile(optimizer='adam', loss='mean_squared_error')

    # Train model
    model.fit(X_train, y_train_scaled, epochs=params['epochs'], batch_size=params['batch_size'], verbose=0)
    
    # Evaluate model
    y_pred = model.predict(X_test)
    y_pred_inverse = scaler.inverse_transform(y_pred)
    y_test_inverse = scaler.inverse_transform(y_test_scaled)
    
    mse = mean_squared_error(y_test_inverse, y_pred_inverse)
    rmse = np.sqrt(mse)

    print(f"RMSE: {rmse}")

    # Simpan hasil tuning
    results.append((params, rmse))
    
    # Simpan kombinasi terbaik
    if rmse < best_rmse:
        best_rmse = rmse
        best_params = params

# Print hasil terbaik
print(f"\nBest RMSE: {best_rmse}")
print(f"Best parameters: {best_params}")

# Display seluruh hasil tuning
for res in results:
    print(f"Params: {res[0]} -> RMSE: {res[1]}")

# Simpan hasil tuning ke Excel
results_df = pd.DataFrame([
    {
        'timestep': r[0]['timestep'],
        'epochs': r[0]['epochs'],
        'batch_size': r[0]['batch_size'],
        'gru_units': r[0]['gru_units'],
        'cnn_filters': r[0]['cnn_filters'],
        'RMSE': r[1]
    }
    for r in results
])

# Simpan ke file Excel
results_df.to_excel("tuning buku_400 80,20.xlsx", index=False)
# Out:
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# RMSE: 31.16099438748068
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# RMSE: 13.378909438275354
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# RMSE: 20.950160206037197
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# RMSE: 23.31767502845998
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 43.627958877642726
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 15.752570624013932
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# RMSE: 21.061998459044418
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 16.68868546499963
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# RMSE: 12.383056443285055
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 9.21629169522206
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 10.947145387346666
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# RMSE: 17.888559450596606
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 9.00181280714107
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# RMSE: 4.410535771067141
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 16.00972484873418
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# RMSE: 34.82401036838218
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# RMSE: 10.848683885300987
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# RMSE: 14.526252391189837
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# RMSE: 19.437533214943542
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 13.63681539258601
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 9.202616127249131
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# RMSE: 9.545092990035837
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# RMSE: 10.900048336384675
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 17.061323002951323
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# RMSE: 11.10955167554435
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# RMSE: 10.079329284838227
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 8.50290606814308
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 8.620258951120135
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# RMSE: 21.06857799603343
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# RMSE: 19.14376778786551
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 4.888174034352106
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 12.793205891603096
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 20.694962562046715
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 5.184219158784599
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 7.601313830361319
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 12.620843550323892
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 4.18580008915286
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# RMSE: 10.437910225078042
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 4.735685287549394
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 14.543053863744635
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# RMSE: 5.785903665280101
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# RMSE: 8.832368362608484
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# RMSE: 7.161346335329548
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# RMSE: 14.939464410883692
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 6.972119469405377
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# RMSE: 4.150376731578161
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# RMSE: 7.735502369503916
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# RMSE: 11.090582700364013
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 7.050228156071346
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 19.76370070637636
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# RMSE: 21.459823302674533
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 5.071524170945705
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 7.064153554238673
#
# Testing combination: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# RMSE: 12.146636630730777
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# RMSE: 6.016218992226642
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# RMSE: 166.54833726528994
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 30.069126952223353
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# RMSE: 26.50008967289872
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# RMSE: 29.781065404892253
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# RMSE: 67.47793808120706
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 5.590425844449531
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# RMSE: 15.67203959588579
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# RMSE: 37.33150728526898
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 12.146269659870462
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 15.610888844974502
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 18.063110242869065
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# RMSE: 7.746056178681235
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# RMSE: 15.096310220520625
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# RMSE: 10.791197670404573
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# RMSE: 12.601060520179697
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# RMSE: 17.91515626992068
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# RMSE: 17.804214572914173
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# RMSE: 20.66261735008941
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# RMSE: 16.543634770575537
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# RMSE: 13.535275755485685
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# RMSE: 16.605276904626283
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# RMSE: 27.76624418125688
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# RMSE: 13.941111069889068
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# RMSE: 31.537783880708513
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# RMSE: 13.848196192206245
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# RMSE: 11.55463313943239
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# RMSE: 10.413265541426822
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# RMSE: 38.33141011276035
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# RMSE: 12.957495958493633
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# RMSE: 6.167806290823255
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 24}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# RMSE: 15.461182744280078
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 12}
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# RMSE: 6.632596731972103
#
# Testing combination: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 24}
# ...
# Params: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 20.694962562046715
# Params: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 5.184219158784599
# Params: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 7.601313830361319
# Params: {'batch_size': 32, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 12.620843550323892
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 4.18580008915286
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 10.437910225078042
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 4.735685287549394
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 14.543053863744635
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 5.785903665280101
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 8.832368362608484
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 7.161346335329548
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 14.939464410883692
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 6.972119469405377
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 4.150376731578161
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 7.735502369503916
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 11.090582700364013
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 7.050228156071346
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 19.76370070637636
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 21.459823302674533
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 5.071524170945705
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 7.064153554238673
# Params: {'batch_size': 32, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 12.146636630730777
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 6.016218992226642
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 166.54833726528994
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 30.069126952223353
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 26.50008967289872
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 29.781065404892253
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 67.47793808120706
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 5.590425844449531
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 15.67203959588579
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 37.33150728526898
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 12.146269659870462
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 15.610888844974502
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 18.063110242869065
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 7.746056178681235
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 15.096310220520625
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 10.791197670404573
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 12.601060520179697
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 17.91515626992068
# Params: {'batch_size': 64, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 17.804214572914173
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 20.66261735008941
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 16.543634770575537
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 13.535275755485685
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 16.605276904626283
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 27.76624418125688
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 13.941111069889068
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 31.537783880708513
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 13.848196192206245
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 11.55463313943239
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 10.413265541426822
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 38.33141011276035
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 12.957495958493633
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 6.167806290823255
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 15.461182744280078
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 6.632596731972103
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 5.050568814526236
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 5.299001178855098
# Params: {'batch_size': 64, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 19.63103231775892
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 14.182837772768105
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 12.409603623024514
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 10.506863354987354
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 12.521481020741694
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 10.25019529211361
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 17.30675298772533
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 10.593618938591938
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 5.319094677809698
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 4.71909154314341
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 10.44654929462891
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 5.633418531214978
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 8.406698882723882
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 8.553269193198496
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 5.971231657489986
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 10.11448023575283
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 4.157458150974298
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 6.100417358629279
# Params: {'batch_size': 64, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 11.860307163828221
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 17.050371193854144
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 18.358375888356417
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 13.831871995996943
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 17.077212816255155
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 78.3203262339039
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 92.37161051909527
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 7.554424912520604
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 11.47133480197368
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 8.518405993676538
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 21.866414047776733
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 18.45388088175107
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 24.819157149031444
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 5.871554810786242
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 5.885973936354671
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 18.70645895810979
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 17.271512096530042
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 13.43394527595592
# Params: {'batch_size': 128, 'cnn_filters': 16, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 20.594290586361417
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 13.783245188916409
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 15.245427936696442
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 11.859706863969869
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 73.60957297952386
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 18.42547750047083
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 29.01244770840321
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 8.64123630876211
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 12.92156533006947
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 15.79987876728397
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 13.985707728467164
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 7.711177589619784
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 20.714360258994546
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 11.554204477789174
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 14.112592370643437
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 11.441720053153004
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 7.9974709566766125
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 10.204484425191954
# Params: {'batch_size': 128, 'cnn_filters': 32, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 20.587779860956925
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 12} -> RMSE: 11.600343491559885
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 10, 'timestep': 24} -> RMSE: 11.167174807035176
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 12} -> RMSE: 6.120059830920503
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 20, 'timestep': 24} -> RMSE: 16.798147514038003
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 12} -> RMSE: 15.363358829905962
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 50, 'gru_units': 100, 'timestep': 24} -> RMSE: 16.96952129629674
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 12} -> RMSE: 6.100320257131124
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 10, 'timestep': 24} -> RMSE: 12.035698524287872
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 12} -> RMSE: 15.252158842646288
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 20, 'timestep': 24} -> RMSE: 13.589268803960342
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 12} -> RMSE: 10.423713058434444
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 100, 'gru_units': 100, 'timestep': 24} -> RMSE: 13.091650879774619
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 12} -> RMSE: 6.708659145222657
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 10, 'timestep': 24} -> RMSE: 6.610537412695124
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 12} -> RMSE: 5.730165223324141
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 20, 'timestep': 24} -> RMSE: 5.152354183634038
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 12} -> RMSE: 6.036604168062544
# Params: {'batch_size': 128, 'cnn_filters': 128, 'epochs': 170, 'gru_units': 100, 'timestep': 24} -> RMSE: 11.432427182375244

# %% [markdown]
# Model CNN-GRU

# %%
# Parameter window size
timestep = 24  # Menggunakan 6 bulan terakhir sebagai input

# Membentuk data input dengan sliding window
def create_sliding_window(data, timestep):
    X, y = [], []
    for i in range(len(data) - timestep):
        X.append(data[i:i+timestep])
        y.append(data[i+timestep])
    return np.array(X), np.array(y)

# Memisahkan fitur dan target
X = buku_400_copy[['Jumlah_buku_dipinjam']].values
y = buku_400_copy[['Jumlah_buku_dipinjam']].values

# Normalisasi data
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Membuat dataset sliding window
X_window, y_window = create_sliding_window(X_scaled, timestep)

# Split data menjadi train dan test (80% training, 20% testing)
split_idx = int(len(X_window) * 0.8)
X_train, X_test = X_window[:split_idx], X_window[split_idx:]
y_train, y_test = y_window[:split_idx], y_window[split_idx:]

# Reshape input menjadi tiga dimensi (samples, timesteps, features)
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# Membangun Model CNN-GRU
model_cnn_gru = Sequential()

# Lapisan CNN
model_cnn_gru.add(Conv1D(filters=128, kernel_size=1, activation='relu', input_shape=(timestep, 1)))
model_cnn_gru.add(MaxPooling1D(pool_size=2))
model_cnn_gru.add(Flatten())

# Ubah kembali ke bentuk tiga dimensi untuk input ke GRU
model_cnn_gru.add(Reshape((1, -1)))

# Lapisan GRU setelah CNN
model_cnn_gru.add(GRU(20, activation='relu'))
model_cnn_gru.add(Dropout(0.2))

# Lapisan output
model_cnn_gru.add(Dense(1))

# Kompilasi model
model_cnn_gru.compile(optimizer='adam', loss='mean_squared_error')

# Latih model
history_model = model_cnn_gru.fit(X_train, y_train, epochs=100, batch_size=32)

# Prediksi pada data uji
y_pred_cnn_gru = model_cnn_gru.predict(X_test)

# Konversi kembali ke skala asli
y_pred_cnn_gru_inverse = scaler.inverse_transform(y_pred_cnn_gru)
y_test_inverse = scaler.inverse_transform(y_test)

# Evaluasi model
mse = mean_squared_error(y_test_inverse, y_pred_cnn_gru_inverse)
rmse = np.sqrt(mse)
mape = mean_absolute_percentage_error(y_test_inverse, y_pred_cnn_gru_inverse) * 100
mae = mean_absolute_error(y_test_inverse, y_pred_cnn_gru_inverse)

print(f"RMSE: {rmse}")
print(f"MAPE: {mape:.2f}%")

# Plot hasil model (data aktual vs prediksi)
plt.figure(figsize=(14, 6))
plt.plot(buku_400_copy['Bulan'][-len(y_test_inverse):], y_test_inverse, label='Actual', color='blue')
plt.plot(buku_400_copy['Bulan'][-len(y_pred_cnn_gru_inverse):], y_pred_cnn_gru_inverse, label='Predicted', linestyle='--', color='red')
plt.title('Perbandingan Hasil Model CNN-GRU pada Data Uji')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Buku Dipinjam')
plt.legend()
plt.show()

# plot loss
plt.figure(figsize=(14, 6))
plt.plot(history_model.history['loss'], label='Train Loss')
plt.title('Loss History')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.1947
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1365
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1388
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1070
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1121
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0813
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0942
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0957
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0629
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0613
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0529
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0597
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0621
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0564
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0507
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0490
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0478
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0384
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0393
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0296
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0264
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0321
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0352
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0248
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0277
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0336
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0212
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0294
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0264
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0366
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0247
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0304
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0170
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0344
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0129
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0226
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0228
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0206
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0233
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0177
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0227
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0196
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0156
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0174
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0236
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0137
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0108
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0179
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0144
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0245
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0113
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0150
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0160
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0181
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0134
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0153
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0146
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0129
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0116
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0108
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0127
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0130
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0100
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0112
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0087
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0133
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0107
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0141
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0089
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0136
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0081
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0096
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0142
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0117
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0095
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0091
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0079
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0163
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0115
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0116
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0124
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0099
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0084
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0106
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0141
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0093
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0052
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0071
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0100
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0097
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0050
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0153
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0112
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0095
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0103
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0060
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0118
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0068
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0074
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0081
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# RMSE: 8.069880335597801
# MAPE: 39.58%

# %%
# Prediksi 12 bulan ke depan menggunakan sliding window
def predict_future(model, last_input, months=12):
    future_predictions = []
    current_input = last_input.copy()

    for _ in range(months):
        prediction = model.predict(current_input.reshape((1, timestep, 1)))
        future_predictions.append(prediction[0, 0])
        
        # Geser input window dengan menambahkan prediksi terbaru
        current_input = np.roll(current_input, -1)
        current_input[-1] = prediction[0, 0]

    return np.array(future_predictions).reshape(-1, 1)

# Gunakan data terakhir sebagai input awal
last_input = X_scaled[-timestep:]
future_preds_scaled = predict_future(model_cnn_gru, last_input, months=12)

# Cek nilai sebelum inverse transform
print("Prediksi dalam skala normalisasi:")
print(future_preds_scaled)

# Konversi kembali ke skala asli
future_preds = scaler.inverse_transform(future_preds_scaled)

# Konversi kembali ke skala asli dan ubah ke bilangan bulat
future_preds = scaler.inverse_transform(future_preds_scaled).astype(int)

# Cek nilai setelah inverse transform
print("Prediksi dalam skala asli:")
print(future_preds)

# Buat label bulan untuk prediksi
future_dates = pd.date_range(start=buku_400_copy['Bulan'].values[-1], periods=12, freq='M')

# Simpan hasil prediksi dalam DataFrame untuk analisis lebih lanjut
predictions_df = pd.DataFrame({'Bulan': future_dates, 'Prediksi': future_preds.flatten()})
print("Hasil prediksi dalam DataFrame:")
print(predictions_df)

# Gabungkan data aktual dan prediksi
combined_dates = np.concatenate([buku_400_copy['Bulan'].values, future_dates])
combined_values = np.concatenate([buku_400_copy['Jumlah_buku_dipinjam'].values, future_preds.flatten()])

# Visualisasi hasil prediksi dengan satu garis tetapi warna berbeda
plt.figure(figsize=(14, 8))

# Plot data aktual dengan warna biru
plt.plot(combined_dates[:len(buku_400_copy)], combined_values[:len(buku_400_copy)], color='blue', label='Actual Data')

# Plot data prediksi dengan warna merah (melanjutkan garis sebelumnya)
plt.plot(combined_dates[len(buku_400_copy)-1:], combined_values[len(buku_400_copy)-1:], color='red', label='CNN-GRU Forecast')

plt.title('Perbandingan Hasil Forecasting Peminjaman Buku')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Buku Dipinjam')
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Prediksi dalam skala normalisasi:
# [[0.11342867]
#  [0.09764878]
#  [0.0988116 ]
#  [0.078925  ]
#  [0.07967242]
#  [0.06568603]
#  [0.06575065]
#  [0.06089732]
#  [0.06125826]
#  [0.05934597]
#  [0.05828439]
#  [0.0575946 ]]
# Prediksi dalam skala asli:
# [[17]
#  [14]
#  [14]
#  [11]
#  [11]
#  [ 9]
#  [ 9]
#  [ 9]
#  [ 9]
#  [ 8]
#  [ 8]
#  [ 8]]
# Hasil prediksi dalam DataFrame:
#         Bulan  Prediksi
# 0  2024-12-31        17
# 1  2025-01-31        14
# 2  2025-02-28        14
# 3  2025-03-31        11
# 4  2025-04-30        11
# 5  2025-05-31         9
# 6  2025-06-30         9
# 7  2025-07-31         9
# 8  2025-08-31         9
# 9  2025-09-30         8
# 10 2025-10-31         8
# 11 2025-11-30         8
# C:\Users\asus\AppData\Local\Temp\ipykernel_22028\887585007.py:35: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=buku_400_copy['Bulan'].values[-1], periods=12, freq='M')
